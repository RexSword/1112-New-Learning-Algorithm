# %% [markdown]
# <a href="https://colab.research.google.com/github/RexSword/1112-New-Learning-Algorithm/blob/main/hw_with_output_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## HW Requirement

# %% [markdown]
# • Implement the code for the 2-layer neural networks in CS231n
# 2021 version with PyTorch (or TensorFlow).
#
# • Once you have the code (regardless of which framework you
# choose above), you will apply your own data.  The training and test
# dataset is 80%:20%.
#
# • You need to run the code with the following hyperparameter
# settings:
#
# ✓ Activation function: tanh, ReLU
#
# ✓ Data preprocessing
#
# ✓ Initial weights: small random number, Xavier or Kaiming/MSRA
# Initialization
#
# ✓ Loss function: without or with the regularization term
# (L2), λ =
# 0.001 or 0.0001
# $$ E(w) = \frac{1}{N}\sum^{N}_{c=1}[𝑓(X^c, w) −y^c]^2
#  + \lambda[\sum^{p}_{i=0}(w^{o}_{i})^2
#  + \sum_{i=1}^{p}\sum_{j=0}^{m}(w_{ij}^H)^2]
# $$
# ✓ Optimizer: gradient descent, Momentum, Adam
#
# ✓ Learning epochs: 100, 200, 300
#
# ✓ Amount of hidden nodes: 5, 8, 11
#
# ✓ Learning rate decay schedule: none and cosine
#
# ✓ Ensembles: top 3 models

# %% [markdown]
# ## Connect to gdrive

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ## Checkout the GPU

# %%
# !nvidia-smi

# %%
# import torch
# # a = torch.Tensor([1000, 1000, 1000]).cuda()  # 大约占用 1.1G 显存

# %% [markdown]
# ## Model

# %%
import torch
from torch import nn, optim, Generator
from torch.utils.data import DataLoader, Dataset, random_split

# %%
from typing import Iterable, Callable, Type
from operator import mul

def product(nums: Iterable[Type], func: Callable[[Type, Type], Type] = mul):
    def _product(nums):
        nonlocal func
        if len(nums) == 1:
            return nums[0]
        return func(nums[-1], _product(nums[:-1]))
    try:
        return _product(nums)
    except Exception as e:
        raise e

# %%
ACTIVES = {
    "relu": nn.ReLU,
    "tanh": nn.Tanh
}
INIT_FUNCS = {
    "small_random": lambda x: nn.init.normal_(tensor=x, mean=0, std=0.01),
    "xavier": lambda x: nn.init.xavier_uniform_(tensor=x) if len(x.shape) > 1 else None,
    "kaiming": lambda x: nn.init.kaiming_uniform_(tensor=x, nonlinearity='relu') if len(x.shape) > 1 else None
}
OPTIM_FUNCS = {
    "sgd": optim.SGD,
    "momentum": lambda param, lr, weight_decay: optim.SGD(params=param, lr=lr, momentum=0.9, weight_decay=weight_decay),
    "adam": optim.Adam
}
SCHEDULERS = {
    "cos": lambda opt: torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=opt, T_max=200)
}

# %%
from collections.abc import Callable
class TwoLayerNetwork(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_classes: int, init_method:Callable, active_func:nn.modules.module.Module) -> None:
        super(TwoLayerNetwork, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        ## first layer
        self.fc1 = nn.Linear(input_size, hidden_size)
        ## activation
        self.active_func = active_func()
        ## initialize
        for param in self.parameters():
            init_method(param)
        ## second layer
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = self.active_func(out)
        out = self.fc2(out)
        return out

# %%
import time

def train(model: TwoLayerNetwork, opt: nn.Module, device: str, epochs: int, learning_rate: float, trainloader: DataLoader, valloader: DataLoader, criterion: nn.modules.loss._Loss, sched: optim.lr_scheduler._LRScheduler, weight_decay:float):
    model.to(device)
    optimizer = opt(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    scheduler = sched(optimizer) if sched else None
    if epochs < 1:
        raise ValueError("Invalid epoch!!")
    else:
        epochs = int(epochs)

    # Record the start time
    start = time.time()
    # Train the model
    for epoch in range(epochs):
        train_loss = 0.0
        train_correct = 0
        model.train()
        for X, y in trainloader:
            X = X.view(-1, model.input_size).to(device)
            y = y.to(device)
            optimizer.zero_grad()
            outputs = model(X)
            loss = criterion(outputs, y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * X.size(0)
            _, predicted = torch.max(outputs.data, 1)
            train_correct += (predicted == y).sum().item()
        train_loss /= len(trainloader.dataset)
        train_accuracy = 100. * train_correct / len(trainloader.dataset)

        # Validate the model
        val_loss = 0.0
        val_correct = 0
        model.eval()
        with torch.no_grad():
            for X, y in valloader:
                X = X.view(-1, model.input_size).to(device)
                y = y.to(device)
                outputs = model(X)
                loss = criterion(outputs, y)
                val_loss += loss.item() * X.size(0)
                _, predicted = torch.max(outputs.data, 1)
                val_correct += (predicted == y).sum().item()
            val_loss /= len(valloader.dataset)
            val_accuracy = 100. * val_correct / len(valloader.dataset)
        if scheduler:
            scheduler.step()
        # record the epoch has the highest train and val accuracy
        if epoch == 0:
            train_result = {"val_acc":(epoch,val_accuracy),"train_acc":(epoch,val_accuracy)}
        else:
            if val_accuracy > train_result["val_acc"][1]:
                train_result["val_acc"] = (epoch,val_accuracy)
            if train_accuracy > train_result["train_acc"][1]:
                train_result["train_acc"] = (epoch,train_accuracy)
        # Print epoch statistics
        print('Epoch [{}/{}], Train Loss: {:.4f}, Train Accuracy: {:.2f}%, Val Loss: {:.4f}, Val Accuracy: {:.2f}%'
              .format(epoch+1, epochs, train_loss, train_accuracy, val_loss, val_accuracy))
    # record the end time
    end = time.time()
    print('Model Training Time: {:.3f} s'.format(end-start))
    train_result["time"] = end-start
    return train_result

# %%
def test(model:nn.Module, device:str, testloader:DataLoader):
    val_correct = 0
    model.eval()
    with torch.no_grad():
        for X, y in testloader:
            X = X.view(-1, model.input_size).to(device)
            y = y.to(device)
            outputs = model(X)
            _, predicted = torch.max(outputs.data, 1)
            val_correct += (predicted == y).sum().item()
        val_accuracy = 100. * val_correct / len(testloader.dataset)
        print("Model Accutacy:{}".format(val_accuracy))
        return val_accuracy

# %% [markdown]
# # Dataset

# %% [markdown]
# ### pytorch dataset

# %%
# load pytorch dataset

from torchvision import datasets, transforms


def getPytorchData():
    # preprocess: flatten, normalize, drop 90%, split
    transform = transforms.transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
    trainset = datasets.FashionMNIST(
        root="./data/", train=True, download=True, transform=transform)
    datum_size = product(trainset[0][0].size())
    class_amount = len(trainset.classes)
    testset = datasets.FashionMNIST(
        root="./data/", train=False, download=True, transform=transform)
    # Split the training set into training and validation sets
    train_count = int(0.08 * len(trainset))
    valid_count = int(0.02 * len(trainset))
    print(train_count, valid_count, len(testset))
    trainset, valset, _ = random_split(
        trainset, (train_count, valid_count, len(trainset)-train_count-valid_count), Generator().manual_seed(42))
    # Create data loaders to load the data in batches
    trainloader = DataLoader(trainset, batch_size=32, shuffle=True)
    valloader = DataLoader(valset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32, shuffle=True)
    return trainloader, valloader, testloader, datum_size, class_amount

# %% [markdown]
# ### customized pytorch dataset

# %%
import pandas as pd
import numpy as np
class HotelReservationDataset(Dataset):
    """Hotel Reservation dataset."""

    def __init__(self, csv_path):
        """
        Args:
            csv_path (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        # 19
        reservations = pd.read_csv(csv_path)
        # 5
        for col in map(lambda x: x[0], filter(lambda x:x[1]=="O", reservations.dtypes.items())):
            d = dict((j, i) for i, j in enumerate(reservations[col].value_counts().index))
            setattr(self, f"labels_of_{col}", d.keys())
            reservations[col]=reservations[col].map(d.__getitem__)
        # 17(drop id)
        self.feature = torch.from_numpy(reservations.iloc[:, 1:-1].to_numpy(dtype=np.float32))
        # two status
        self.booking_status = torch.reshape(torch.tensor(reservations.iloc[:, -1:].to_numpy()), shape=(len(self.feature),))
        self.classes = list(getattr(self, f"labels_of_{reservations.columns[-1]}"))
    def __len__(self):
        return len(self.booking_status)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        return self.feature[idx], self.booking_status[idx]

# kaggle: ahsan81/hotel-reservations-classification-dataset
def getCustomizedData():
    # preprocess
    dataset = HotelReservationDataset(
        csv_path=r"D:\dataset\archive\Hotel Reservations.csv")
    class_amount = len(dataset.classes)
    # train test split
    train_count = int(0.7 * len(dataset))
    valid_count = int(0.2 * len(dataset))
    test_count = len(dataset) - train_count - valid_count
    print(train_count, valid_count, test_count)
    trainset, valset, testset = random_split(
        dataset, (train_count, valid_count, test_count), Generator().manual_seed(42))
    datum_size = product(trainset[0][0].size())
    # set loaders
    trainloader = DataLoader(trainset, batch_size=32, shuffle=True)
    valloader = DataLoader(valset, batch_size=32, shuffle=True)
    testloader = DataLoader(testset, batch_size=32, shuffle=True)
    return trainloader, valloader, testloader, datum_size, class_amount

# %% [markdown]
# ### kaggle dataset

# %%
# # download data(zipped csv) from kaggle with username and apikey
# import os
# import json
# with open("kaggle.json", "r") as j:
#     for (k, v) in json.load(j).items():
#         os.environ[k] = v
# from kaggle.api.kaggle_api_extended import KaggleApi
# api = KaggleApi()
# api.authenticate()
# # https://www.kaggle.com/datasets/uciml/iris/download?datasetVersionNumber=2
# # owner/datasetname
# api.dataset_download_files('uciml/iris', path="./data/")

# %% [markdown]
# ## Training

# %%
import sys


def training_schedule():
    sys.stdout = open("./result/", "w")
    # processor
    device = "cuda" if torch.cuda.is_available(
    ) else "mps" if torch.backends.mps.is_available() else "cpu"
    # hyper parameters
    trainloader, valloader, testloader, input_size, output_size = getPytorchData()
    learning_rate = 0.001
    criterion = nn.CrossEntropyLoss()
    # ✓ Amount of hidden nodes: 5, 8, 11
    for hidden_size in (5, 8, 11):
        # ✓ Learning epochs: 100, 200, 300
        for epochs in (100, 200, 300):
            # Create model, optimizer, scheduler
            for (init, method) in INIT_FUNCS.items():
                for (active, func) in ACTIVES.items():
                    # ✓ Activation function: tanh, ReLU
                    # ✓ Initial weights: small random number, Xavier or Kaiming/MSRA Initialization
                    model = TwoLayerNetwork(input_size, hidden_size, output_size,
                                            init_method=method, active_func=func).to(device)
                    # ✓ Optimizer: gradient descent, Momentum, Adam
                    for (optimize, optm) in OPTIM_FUNCS.items():
                        # ✓ Learning rate decay schedule: none and cosine
                        for (schedule, schd) in SCHEDULERS.items():
                            # ✓ Loss function: without or with L2, λ = 0.001 or 0.0001
                            for weight_decay in (0.0, 0.001, 0.0001):
                                print(hidden_size, epochs, init, active,optimize, schedule, "start")
                                train(model=model, optm=optm, device=device, epochs=epochs, learning_rate=learning_rate,
                                      trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
                                test(model=model, device=device, testloader=testloader)

# %%
import datetime

def _training_schedule():
    
    FILE_PATH = "./{}.txt".format(datetime.date.today())
    
    # alternative for colab only
    # FILE_PATH = "/content/gdrive/MyDrive/{}.txt".format(datetime.date.today())
    counter = 1
    test_result = {}

    with open(FILE_PATH,"w") as f:
      f.write("{}\n\n".format(datetime.datetime.today()))

    def write_spec_to_file():
        with open(FILE_PATH,"a") as f:
            f.write("- Model {} -\n".format(counter))
            f.write("hidden nodes: {} \nepochs: {} \ninit: {} \nactive: {} \noptimize: {} \nschedule: {} \nweight decay: {}\n".format(
                hidden_size, epochs, init, active, optimize, schedule, weight_decay))
            f.write("-"*50)

    def write_result_to_file(rs, tr_rs):
        with open(FILE_PATH,"a") as f:
            f.write("\nModel Accuracy:{}%\n".format(rs))
            f.write("Training Time:{:.3f} s\n".format(tr_rs["time"]))
            f.write("Epoch with hightest Train accuracy:{}, {:.2f}%\n".format(*tr_rs["train_acc"]))
            f.write("Epoch with hightest Val accuracy:{}, {:.2f}%\n".format(*tr_rs["val_acc"]))
            f.write("-"*50+"\n")

    # processor
    device = "cuda" if torch.cuda.is_available(
    ) else "mps" if torch.backends.mps.is_available() else "cpu"
    
    # hyper parameters
    trainloader, valloader, testloader, input_size, output_size = getPytorchData()
    learning_rate = 0.001
    criterion = nn.CrossEntropyLoss()
    
    hidden_size = 5
    epochs = 100
    init = "small_random"
    method = INIT_FUNCS[init]
    active = "relu"
    func = ACTIVES[active]
    optimize = "sgd"
    optm = OPTIM_FUNCS[optimize]
    schedule = None
    schd = schedule
    weight_decay = 0.0
    
    # ✓ Amount of hidden nodes: 5, 8, 11
    for hidden_size in (5, 8, 11):
        model = TwoLayerNetwork(input_size=input_size, hidden_size=hidden_size,
                                num_classes=output_size, init_method=method, active_func=func)
        print(hidden_size, epochs, init, active, optimize, schedule, weight_decay, "start")
        write_spec_to_file()

        train_rs = train(model=model, opt=optm, device=device, epochs=epochs, learning_rate=learning_rate,
              trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
        result = test(model=model, device=device, testloader=testloader)
        write_result_to_file(result, train_rs)

        test_result["model{}".format(counter)] = result
        counter += 1
    # ✓ Learning epochs: 100, 200, 300
    for epochs in (100, 200, 300):
        if epochs == 100:
          continue        
        model = TwoLayerNetwork(input_size=input_size, hidden_size=hidden_size,
                                num_classes=output_size, init_method=method, active_func=func)
        print(hidden_size, epochs, init, active, optimize, schedule, weight_decay, "start")
        write_spec_to_file()

        train_rs = train(model=model, opt=optm, device=device, epochs=epochs, learning_rate=learning_rate,
              trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
        result = test(model=model, device=device, testloader=testloader)
        write_result_to_file(result, train_rs)


        test_result["model{}".format(counter)] = result
        counter += 1

    # Create model, optimizer, scheduler
    for (init, method) in INIT_FUNCS.items():
        if init == "small_random":
          continue

        model = TwoLayerNetwork(input_size=input_size, hidden_size=hidden_size,
                                num_classes=output_size, init_method=method, active_func=func)
        print(hidden_size, epochs, init, active, optimize, schedule, weight_decay, "start")
        write_spec_to_file()

        train_rs = train(model=model, opt=optm, device=device, epochs=epochs, learning_rate=learning_rate,
              trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
        result = test(model=model, device=device, testloader=testloader)
        write_result_to_file(result, train_rs)

        test_result["model{}".format(counter)] = result
        counter += 1
    for (active, func) in ACTIVES.items():
        if active == "relu":
          continue
        model = TwoLayerNetwork(input_size=input_size, hidden_size=hidden_size,
                                num_classes=output_size, init_method=method, active_func=func)
        print(hidden_size, epochs, init, active, optimize, schedule, weight_decay, "start")
        write_spec_to_file()

        train_rs = train(model=model, opt=optm, device=device, epochs=epochs, learning_rate=learning_rate,
              trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
        result = test(model=model, device=device, testloader=testloader)
        write_result_to_file(result, train_rs)

        test_result["model{}".format(counter)] = result
        counter += 1
    
    # ✓ Activation function: tanh, ReLU
    # ✓ Initial weights: small random number, Xavier or Kaiming/MSRA Initialization
    model = TwoLayerNetwork(input_size=input_size, hidden_size=hidden_size,
                            num_classes=output_size, init_method=method, active_func=func)
    
    # ✓ Optimizer: gradient descent, Momentum, Adam
    for (optimize, optm) in OPTIM_FUNCS.items():
        if optimize == "sgd":
          continue

        print(hidden_size, epochs, init, active, optimize, schedule, weight_decay, "start")
        write_spec_to_file()

        train_rs = train(model=model, opt=optm, device=device, epochs=epochs, learning_rate=learning_rate,
              trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
        result = test(model=model, device=device, testloader=testloader)
        write_result_to_file(result, train_rs)

        test_result["model{}".format(counter)] = result
        counter += 1
    # ✓ Learning rate decay schedule: none and cosine
    for (schedule, schd) in SCHEDULERS.items():
        print(hidden_size, epochs, init, active, optimize, schedule, weight_decay, "start")
        write_spec_to_file()

        train_rs = train(model=model, opt=optm, device=device, epochs=epochs, learning_rate=learning_rate,
              trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
        result = test(model=model, device=device, testloader=testloader)
        write_result_to_file(result, train_rs)

        test_result["model{}".format(counter)] = result
        counter += 1
    # ✓ Loss function: without or with L2, λ = 0.001 or 0.0001
    for weight_decay in (0.0, 0.001, 0.0001):
        if weight_decay == 0.0:
          continue

        print(hidden_size, epochs, init, active, optimize, schedule, weight_decay, "start")
        write_spec_to_file()
        
        train_rs = train(model=model, opt=optm, device=device, epochs=epochs, learning_rate=learning_rate,
              trainloader=trainloader, valloader=valloader, criterion=criterion, sched=schd, weight_decay=weight_decay)
        result = test(model=model, device=device, testloader=testloader)
        write_result_to_file(result, train_rs)

        test_result["model{}".format(counter)] = result
        counter += 1

    top3 = sorted(test_result, key=test_result.get, reverse=True)[:3]
    print("\nTop 3 Model:{}\n".format(','.join(top3)))
    with open(FILE_PATH,"a") as f:
        f.write("\nTop 3 Model:{}\n".format(','.join(top3)))

# %%
_training_schedule()
# Out:
# 4800 1200 10000
# 5 100 small_random relu sgd None 0.0 start
# Epoch [1/100], Train Loss: 2.2902, Train Accuracy: 11.38%, Val Loss: 2.2293, Val Accuracy: 13.83%
# Epoch [2/100], Train Loss: 2.1710, Train Accuracy: 17.27%, Val Loss: 2.1293, Val Accuracy: 17.25%
# Epoch [3/100], Train Loss: 2.0798, Train Accuracy: 19.04%, Val Loss: 2.0451, Val Accuracy: 20.92%
# Epoch [4/100], Train Loss: 1.9964, Train Accuracy: 24.60%, Val Loss: 1.9627, Val Accuracy: 27.92%
# Epoch [5/100], Train Loss: 1.9139, Train Accuracy: 31.96%, Val Loss: 1.8789, Val Accuracy: 34.25%
# Epoch [6/100], Train Loss: 1.8297, Train Accuracy: 38.23%, Val Loss: 1.7933, Val Accuracy: 39.42%
# Epoch [7/100], Train Loss: 1.7443, Train Accuracy: 41.75%, Val Loss: 1.7063, Val Accuracy: 42.92%
# Epoch [8/100], Train Loss: 1.6609, Train Accuracy: 44.19%, Val Loss: 1.6245, Val Accuracy: 44.67%
# Epoch [9/100], Train Loss: 1.5836, Train Accuracy: 46.73%, Val Loss: 1.5500, Val Accuracy: 47.50%
# Epoch [10/100], Train Loss: 1.5145, Train Accuracy: 48.31%, Val Loss: 1.4842, Val Accuracy: 49.25%
# Epoch [11/100], Train Loss: 1.4535, Train Accuracy: 49.73%, Val Loss: 1.4258, Val Accuracy: 50.25%
# Epoch [12/100], Train Loss: 1.3994, Train Accuracy: 51.23%, Val Loss: 1.3748, Val Accuracy: 53.58%
# Epoch [13/100], Train Loss: 1.3513, Train Accuracy: 52.94%, Val Loss: 1.3288, Val Accuracy: 56.08%
# Epoch [14/100], Train Loss: 1.3080, Train Accuracy: 55.94%, Val Loss: 1.2875, Val Accuracy: 58.33%
# Epoch [15/100], Train Loss: 1.2687, Train Accuracy: 57.40%, Val Loss: 1.2497, Val Accuracy: 60.08%
# Epoch [16/100], Train Loss: 1.2328, Train Accuracy: 58.40%, Val Loss: 1.2153, Val Accuracy: 60.50%
# Epoch [17/100], Train Loss: 1.1994, Train Accuracy: 59.90%, Val Loss: 1.1832, Val Accuracy: 62.25%
# Epoch [18/100], Train Loss: 1.1686, Train Accuracy: 60.17%, Val Loss: 1.1538, Val Accuracy: 62.83%
# Epoch [19/100], Train Loss: 1.1394, Train Accuracy: 61.12%, Val Loss: 1.1259, Val Accuracy: 62.83%
# Epoch [20/100], Train Loss: 1.1121, Train Accuracy: 61.58%, Val Loss: 1.0997, Val Accuracy: 63.25%
# Epoch [21/100], Train Loss: 1.0863, Train Accuracy: 62.65%, Val Loss: 1.0743, Val Accuracy: 63.42%
# Epoch [22/100], Train Loss: 1.0616, Train Accuracy: 62.94%, Val Loss: 1.0506, Val Accuracy: 64.83%
# Epoch [23/100], Train Loss: 1.0382, Train Accuracy: 63.88%, Val Loss: 1.0276, Val Accuracy: 65.00%
# Epoch [24/100], Train Loss: 1.0160, Train Accuracy: 64.50%, Val Loss: 1.0069, Val Accuracy: 65.92%
# Epoch [25/100], Train Loss: 0.9946, Train Accuracy: 65.42%, Val Loss: 0.9863, Val Accuracy: 66.08%
# Epoch [26/100], Train Loss: 0.9741, Train Accuracy: 66.00%, Val Loss: 0.9667, Val Accuracy: 67.25%
# Epoch [27/100], Train Loss: 0.9540, Train Accuracy: 66.83%, Val Loss: 0.9480, Val Accuracy: 67.83%
# Epoch [28/100], Train Loss: 0.9353, Train Accuracy: 67.75%, Val Loss: 0.9300, Val Accuracy: 68.17%
# Epoch [29/100], Train Loss: 0.9178, Train Accuracy: 68.21%, Val Loss: 0.9132, Val Accuracy: 68.92%
# Epoch [30/100], Train Loss: 0.9018, Train Accuracy: 68.71%, Val Loss: 0.8981, Val Accuracy: 69.58%
# Epoch [31/100], Train Loss: 0.8870, Train Accuracy: 69.00%, Val Loss: 0.8842, Val Accuracy: 69.58%
# Epoch [32/100], Train Loss: 0.8732, Train Accuracy: 69.42%, Val Loss: 0.8719, Val Accuracy: 69.17%
# Epoch [33/100], Train Loss: 0.8610, Train Accuracy: 69.48%, Val Loss: 0.8609, Val Accuracy: 69.42%
# Epoch [34/100], Train Loss: 0.8495, Train Accuracy: 70.23%, Val Loss: 0.8501, Val Accuracy: 69.92%
# Epoch [35/100], Train Loss: 0.8390, Train Accuracy: 70.25%, Val Loss: 0.8416, Val Accuracy: 69.83%
# Epoch [36/100], Train Loss: 0.8292, Train Accuracy: 70.46%, Val Loss: 0.8304, Val Accuracy: 70.42%
# Epoch [37/100], Train Loss: 0.8205, Train Accuracy: 70.56%, Val Loss: 0.8241, Val Accuracy: 70.75%
# Epoch [38/100], Train Loss: 0.8123, Train Accuracy: 70.73%, Val Loss: 0.8161, Val Accuracy: 70.17%
# Epoch [39/100], Train Loss: 0.8048, Train Accuracy: 70.92%, Val Loss: 0.8078, Val Accuracy: 70.58%
# Epoch [40/100], Train Loss: 0.7973, Train Accuracy: 71.25%, Val Loss: 0.8016, Val Accuracy: 70.50%
# Epoch [41/100], Train Loss: 0.7907, Train Accuracy: 71.35%, Val Loss: 0.7959, Val Accuracy: 71.17%
# Epoch [42/100], Train Loss: 0.7846, Train Accuracy: 71.21%, Val Loss: 0.7901, Val Accuracy: 71.08%
# Epoch [43/100], Train Loss: 0.7783, Train Accuracy: 71.29%, Val Loss: 0.7851, Val Accuracy: 70.75%
# Epoch [44/100], Train Loss: 0.7725, Train Accuracy: 71.56%, Val Loss: 0.7792, Val Accuracy: 71.25%
# Epoch [45/100], Train Loss: 0.7674, Train Accuracy: 71.85%, Val Loss: 0.7740, Val Accuracy: 71.42%
# Epoch [46/100], Train Loss: 0.7625, Train Accuracy: 71.90%, Val Loss: 0.7711, Val Accuracy: 71.42%
# Epoch [47/100], Train Loss: 0.7575, Train Accuracy: 72.06%, Val Loss: 0.7679, Val Accuracy: 71.33%
# Epoch [48/100], Train Loss: 0.7534, Train Accuracy: 71.90%, Val Loss: 0.7629, Val Accuracy: 71.00%
# Epoch [49/100], Train Loss: 0.7485, Train Accuracy: 71.71%, Val Loss: 0.7581, Val Accuracy: 71.50%
# Epoch [50/100], Train Loss: 0.7449, Train Accuracy: 72.27%, Val Loss: 0.7545, Val Accuracy: 71.33%
# Epoch [51/100], Train Loss: 0.7408, Train Accuracy: 72.50%, Val Loss: 0.7516, Val Accuracy: 71.33%
# Epoch [52/100], Train Loss: 0.7372, Train Accuracy: 72.46%, Val Loss: 0.7480, Val Accuracy: 71.58%
# Epoch [53/100], Train Loss: 0.7334, Train Accuracy: 72.62%, Val Loss: 0.7466, Val Accuracy: 71.33%
# Epoch [54/100], Train Loss: 0.7298, Train Accuracy: 72.54%, Val Loss: 0.7420, Val Accuracy: 71.92%
# Epoch [55/100], Train Loss: 0.7265, Train Accuracy: 72.88%, Val Loss: 0.7392, Val Accuracy: 71.75%
# Epoch [56/100], Train Loss: 0.7236, Train Accuracy: 72.73%, Val Loss: 0.7363, Val Accuracy: 71.83%
# Epoch [57/100], Train Loss: 0.7204, Train Accuracy: 72.96%, Val Loss: 0.7330, Val Accuracy: 72.00%
# Epoch [58/100], Train Loss: 0.7174, Train Accuracy: 72.77%, Val Loss: 0.7311, Val Accuracy: 72.08%
# Epoch [59/100], Train Loss: 0.7146, Train Accuracy: 73.00%, Val Loss: 0.7286, Val Accuracy: 72.25%
# Epoch [60/100], Train Loss: 0.7115, Train Accuracy: 73.06%, Val Loss: 0.7273, Val Accuracy: 72.42%
# Epoch [61/100], Train Loss: 0.7087, Train Accuracy: 73.48%, Val Loss: 0.7251, Val Accuracy: 71.83%
# Epoch [62/100], Train Loss: 0.7064, Train Accuracy: 73.31%, Val Loss: 0.7224, Val Accuracy: 72.33%
# Epoch [63/100], Train Loss: 0.7040, Train Accuracy: 73.12%, Val Loss: 0.7209, Val Accuracy: 72.42%
# Epoch [64/100], Train Loss: 0.7013, Train Accuracy: 73.29%, Val Loss: 0.7177, Val Accuracy: 72.50%
# Epoch [65/100], Train Loss: 0.6991, Train Accuracy: 73.27%, Val Loss: 0.7166, Val Accuracy: 72.50%
# Epoch [66/100], Train Loss: 0.6967, Train Accuracy: 73.23%, Val Loss: 0.7140, Val Accuracy: 72.67%
# Epoch [67/100], Train Loss: 0.6942, Train Accuracy: 73.92%, Val Loss: 0.7132, Val Accuracy: 72.50%
# Epoch [68/100], Train Loss: 0.6920, Train Accuracy: 73.56%, Val Loss: 0.7107, Val Accuracy: 73.00%
# Epoch [69/100], Train Loss: 0.6901, Train Accuracy: 73.96%, Val Loss: 0.7098, Val Accuracy: 72.75%
# Epoch [70/100], Train Loss: 0.6881, Train Accuracy: 73.73%, Val Loss: 0.7065, Val Accuracy: 73.08%
# Epoch [71/100], Train Loss: 0.6859, Train Accuracy: 73.85%, Val Loss: 0.7056, Val Accuracy: 72.83%
# Epoch [72/100], Train Loss: 0.6839, Train Accuracy: 73.85%, Val Loss: 0.7022, Val Accuracy: 73.50%
# Epoch [73/100], Train Loss: 0.6821, Train Accuracy: 74.08%, Val Loss: 0.7014, Val Accuracy: 73.58%
# Epoch [74/100], Train Loss: 0.6797, Train Accuracy: 74.10%, Val Loss: 0.7007, Val Accuracy: 73.50%
# Epoch [75/100], Train Loss: 0.6779, Train Accuracy: 74.19%, Val Loss: 0.6983, Val Accuracy: 73.58%
# Epoch [76/100], Train Loss: 0.6762, Train Accuracy: 74.23%, Val Loss: 0.6971, Val Accuracy: 73.58%
# Epoch [77/100], Train Loss: 0.6743, Train Accuracy: 74.17%, Val Loss: 0.6948, Val Accuracy: 74.00%
# Epoch [78/100], Train Loss: 0.6726, Train Accuracy: 74.15%, Val Loss: 0.6944, Val Accuracy: 73.33%
# Epoch [79/100], Train Loss: 0.6710, Train Accuracy: 74.56%, Val Loss: 0.6937, Val Accuracy: 73.58%
# Epoch [80/100], Train Loss: 0.6693, Train Accuracy: 74.54%, Val Loss: 0.6919, Val Accuracy: 73.67%
# Epoch [81/100], Train Loss: 0.6677, Train Accuracy: 74.62%, Val Loss: 0.6916, Val Accuracy: 73.50%
# Epoch [82/100], Train Loss: 0.6660, Train Accuracy: 74.67%, Val Loss: 0.6884, Val Accuracy: 73.58%
# Epoch [83/100], Train Loss: 0.6642, Train Accuracy: 74.62%, Val Loss: 0.6890, Val Accuracy: 73.67%
# Epoch [84/100], Train Loss: 0.6626, Train Accuracy: 74.81%, Val Loss: 0.6876, Val Accuracy: 73.50%
# Epoch [85/100], Train Loss: 0.6617, Train Accuracy: 75.04%, Val Loss: 0.6854, Val Accuracy: 73.83%
# Epoch [86/100], Train Loss: 0.6598, Train Accuracy: 75.00%, Val Loss: 0.6839, Val Accuracy: 73.75%
# Epoch [87/100], Train Loss: 0.6582, Train Accuracy: 75.29%, Val Loss: 0.6835, Val Accuracy: 73.83%
# Epoch [88/100], Train Loss: 0.6571, Train Accuracy: 74.94%, Val Loss: 0.6820, Val Accuracy: 73.92%
# Epoch [89/100], Train Loss: 0.6552, Train Accuracy: 75.40%, Val Loss: 0.6807, Val Accuracy: 74.08%
# Epoch [90/100], Train Loss: 0.6537, Train Accuracy: 75.12%, Val Loss: 0.6794, Val Accuracy: 74.25%
# Epoch [91/100], Train Loss: 0.6524, Train Accuracy: 75.25%, Val Loss: 0.6779, Val Accuracy: 74.42%
# Epoch [92/100], Train Loss: 0.6511, Train Accuracy: 75.40%, Val Loss: 0.6766, Val Accuracy: 74.42%
# Epoch [93/100], Train Loss: 0.6497, Train Accuracy: 75.48%, Val Loss: 0.6764, Val Accuracy: 74.17%
# Epoch [94/100], Train Loss: 0.6484, Train Accuracy: 75.50%, Val Loss: 0.6754, Val Accuracy: 74.42%
# Epoch [95/100], Train Loss: 0.6468, Train Accuracy: 75.50%, Val Loss: 0.6755, Val Accuracy: 74.25%
# Epoch [96/100], Train Loss: 0.6457, Train Accuracy: 75.33%, Val Loss: 0.6730, Val Accuracy: 74.50%
# Epoch [97/100], Train Loss: 0.6441, Train Accuracy: 75.44%, Val Loss: 0.6718, Val Accuracy: 74.92%
# Epoch [98/100], Train Loss: 0.6430, Train Accuracy: 75.81%, Val Loss: 0.6716, Val Accuracy: 74.83%
# Epoch [99/100], Train Loss: 0.6417, Train Accuracy: 75.85%, Val Loss: 0.6705, Val Accuracy: 74.92%
# Epoch [100/100], Train Loss: 0.6406, Train Accuracy: 75.65%, Val Loss: 0.6690, Val Accuracy: 75.17%
# Model Training Time: 231.941 s
# Model Accutacy:75.07
# 8 100 small_random relu sgd None 0.0 start
# Epoch [1/100], Train Loss: 2.2624, Train Accuracy: 10.60%, Val Loss: 2.1791, Val Accuracy: 11.33%
# Epoch [2/100], Train Loss: 2.1204, Train Accuracy: 23.42%, Val Loss: 2.0598, Val Accuracy: 31.58%
# Epoch [3/100], Train Loss: 2.0167, Train Accuracy: 38.31%, Val Loss: 1.9620, Val Accuracy: 42.33%
# Epoch [4/100], Train Loss: 1.9225, Train Accuracy: 45.25%, Val Loss: 1.8658, Val Accuracy: 46.83%
# Epoch [5/100], Train Loss: 1.8268, Train Accuracy: 49.98%, Val Loss: 1.7655, Val Accuracy: 50.67%
# Epoch [6/100], Train Loss: 1.7270, Train Accuracy: 52.77%, Val Loss: 1.6603, Val Accuracy: 52.83%
# Epoch [7/100], Train Loss: 1.6241, Train Accuracy: 54.42%, Val Loss: 1.5528, Val Accuracy: 54.42%
# Epoch [8/100], Train Loss: 1.5213, Train Accuracy: 55.54%, Val Loss: 1.4506, Val Accuracy: 54.75%
# Epoch [9/100], Train Loss: 1.4271, Train Accuracy: 55.98%, Val Loss: 1.3603, Val Accuracy: 56.08%
# Epoch [10/100], Train Loss: 1.3434, Train Accuracy: 56.94%, Val Loss: 1.2810, Val Accuracy: 59.42%
# Epoch [11/100], Train Loss: 1.2697, Train Accuracy: 59.81%, Val Loss: 1.2108, Val Accuracy: 62.75%
# Epoch [12/100], Train Loss: 1.2058, Train Accuracy: 62.54%, Val Loss: 1.1534, Val Accuracy: 64.33%
# Epoch [13/100], Train Loss: 1.1513, Train Accuracy: 65.17%, Val Loss: 1.1018, Val Accuracy: 65.33%
# Epoch [14/100], Train Loss: 1.1046, Train Accuracy: 66.54%, Val Loss: 1.0599, Val Accuracy: 66.67%
# Epoch [15/100], Train Loss: 1.0643, Train Accuracy: 67.69%, Val Loss: 1.0214, Val Accuracy: 68.58%
# Epoch [16/100], Train Loss: 1.0299, Train Accuracy: 68.54%, Val Loss: 0.9886, Val Accuracy: 69.17%
# Epoch [17/100], Train Loss: 0.9993, Train Accuracy: 69.12%, Val Loss: 0.9606, Val Accuracy: 69.25%
# Epoch [18/100], Train Loss: 0.9720, Train Accuracy: 69.31%, Val Loss: 0.9336, Val Accuracy: 69.83%
# Epoch [19/100], Train Loss: 0.9478, Train Accuracy: 69.50%, Val Loss: 0.9115, Val Accuracy: 70.25%
# Epoch [20/100], Train Loss: 0.9261, Train Accuracy: 69.83%, Val Loss: 0.8899, Val Accuracy: 70.83%
# Epoch [21/100], Train Loss: 0.9065, Train Accuracy: 70.00%, Val Loss: 0.8704, Val Accuracy: 71.42%
# Epoch [22/100], Train Loss: 0.8884, Train Accuracy: 70.62%, Val Loss: 0.8545, Val Accuracy: 70.67%
# Epoch [23/100], Train Loss: 0.8722, Train Accuracy: 70.69%, Val Loss: 0.8376, Val Accuracy: 71.08%
# Epoch [24/100], Train Loss: 0.8573, Train Accuracy: 71.08%, Val Loss: 0.8229, Val Accuracy: 71.25%
# Epoch [25/100], Train Loss: 0.8436, Train Accuracy: 71.21%, Val Loss: 0.8107, Val Accuracy: 71.33%
# Epoch [26/100], Train Loss: 0.8310, Train Accuracy: 71.38%, Val Loss: 0.7976, Val Accuracy: 71.50%
# Epoch [27/100], Train Loss: 0.8189, Train Accuracy: 71.67%, Val Loss: 0.7852, Val Accuracy: 71.58%
# Epoch [28/100], Train Loss: 0.8082, Train Accuracy: 71.79%, Val Loss: 0.7751, Val Accuracy: 72.00%
# Epoch [29/100], Train Loss: 0.7982, Train Accuracy: 72.42%, Val Loss: 0.7657, Val Accuracy: 72.42%
# Epoch [30/100], Train Loss: 0.7885, Train Accuracy: 72.17%, Val Loss: 0.7554, Val Accuracy: 73.25%
# Epoch [31/100], Train Loss: 0.7799, Train Accuracy: 72.69%, Val Loss: 0.7491, Val Accuracy: 73.08%
# Epoch [32/100], Train Loss: 0.7717, Train Accuracy: 72.69%, Val Loss: 0.7400, Val Accuracy: 73.25%
# Epoch [33/100], Train Loss: 0.7639, Train Accuracy: 72.88%, Val Loss: 0.7334, Val Accuracy: 73.83%
# Epoch [34/100], Train Loss: 0.7568, Train Accuracy: 73.33%, Val Loss: 0.7245, Val Accuracy: 74.17%
# Epoch [35/100], Train Loss: 0.7497, Train Accuracy: 73.08%, Val Loss: 0.7202, Val Accuracy: 74.25%
# Epoch [36/100], Train Loss: 0.7434, Train Accuracy: 73.54%, Val Loss: 0.7123, Val Accuracy: 74.83%
# Epoch [37/100], Train Loss: 0.7375, Train Accuracy: 73.54%, Val Loss: 0.7067, Val Accuracy: 75.08%
# Epoch [38/100], Train Loss: 0.7315, Train Accuracy: 73.75%, Val Loss: 0.7026, Val Accuracy: 74.00%
# Epoch [39/100], Train Loss: 0.7261, Train Accuracy: 74.10%, Val Loss: 0.6974, Val Accuracy: 74.50%
# Epoch [40/100], Train Loss: 0.7208, Train Accuracy: 74.06%, Val Loss: 0.6926, Val Accuracy: 74.83%
# Epoch [41/100], Train Loss: 0.7161, Train Accuracy: 74.12%, Val Loss: 0.6875, Val Accuracy: 75.17%
# Epoch [42/100], Train Loss: 0.7112, Train Accuracy: 74.27%, Val Loss: 0.6832, Val Accuracy: 75.42%
# Epoch [43/100], Train Loss: 0.7063, Train Accuracy: 74.29%, Val Loss: 0.6781, Val Accuracy: 75.25%
# Epoch [44/100], Train Loss: 0.7019, Train Accuracy: 74.33%, Val Loss: 0.6734, Val Accuracy: 75.25%
# Epoch [45/100], Train Loss: 0.6979, Train Accuracy: 74.42%, Val Loss: 0.6703, Val Accuracy: 75.42%
# Epoch [46/100], Train Loss: 0.6936, Train Accuracy: 74.62%, Val Loss: 0.6673, Val Accuracy: 75.83%
# Epoch [47/100], Train Loss: 0.6897, Train Accuracy: 74.69%, Val Loss: 0.6643, Val Accuracy: 75.92%
# Epoch [48/100], Train Loss: 0.6861, Train Accuracy: 74.73%, Val Loss: 0.6606, Val Accuracy: 75.50%
# Epoch [49/100], Train Loss: 0.6820, Train Accuracy: 75.10%, Val Loss: 0.6592, Val Accuracy: 75.75%
# Epoch [50/100], Train Loss: 0.6784, Train Accuracy: 74.98%, Val Loss: 0.6533, Val Accuracy: 76.50%
# Epoch [51/100], Train Loss: 0.6752, Train Accuracy: 75.15%, Val Loss: 0.6511, Val Accuracy: 76.58%
# Epoch [52/100], Train Loss: 0.6717, Train Accuracy: 75.29%, Val Loss: 0.6463, Val Accuracy: 76.08%
# Epoch [53/100], Train Loss: 0.6687, Train Accuracy: 75.50%, Val Loss: 0.6457, Val Accuracy: 76.42%
# Epoch [54/100], Train Loss: 0.6655, Train Accuracy: 75.40%, Val Loss: 0.6434, Val Accuracy: 76.42%
# Epoch [55/100], Train Loss: 0.6625, Train Accuracy: 75.77%, Val Loss: 0.6388, Val Accuracy: 76.50%
# Epoch [56/100], Train Loss: 0.6593, Train Accuracy: 75.81%, Val Loss: 0.6366, Val Accuracy: 76.50%
# Epoch [57/100], Train Loss: 0.6564, Train Accuracy: 76.02%, Val Loss: 0.6347, Val Accuracy: 76.92%
# Epoch [58/100], Train Loss: 0.6536, Train Accuracy: 75.79%, Val Loss: 0.6313, Val Accuracy: 77.33%
# Epoch [59/100], Train Loss: 0.6508, Train Accuracy: 75.83%, Val Loss: 0.6296, Val Accuracy: 76.92%
# Epoch [60/100], Train Loss: 0.6483, Train Accuracy: 76.33%, Val Loss: 0.6271, Val Accuracy: 77.17%
# Epoch [61/100], Train Loss: 0.6454, Train Accuracy: 76.19%, Val Loss: 0.6250, Val Accuracy: 76.92%
# Epoch [62/100], Train Loss: 0.6430, Train Accuracy: 76.25%, Val Loss: 0.6228, Val Accuracy: 77.42%
# Epoch [63/100], Train Loss: 0.6405, Train Accuracy: 76.27%, Val Loss: 0.6197, Val Accuracy: 77.25%
# Epoch [64/100], Train Loss: 0.6378, Train Accuracy: 76.33%, Val Loss: 0.6181, Val Accuracy: 77.67%
# Epoch [65/100], Train Loss: 0.6356, Train Accuracy: 76.54%, Val Loss: 0.6171, Val Accuracy: 77.92%
# Epoch [66/100], Train Loss: 0.6332, Train Accuracy: 76.65%, Val Loss: 0.6148, Val Accuracy: 77.75%
# Epoch [67/100], Train Loss: 0.6308, Train Accuracy: 76.71%, Val Loss: 0.6117, Val Accuracy: 78.00%
# Epoch [68/100], Train Loss: 0.6282, Train Accuracy: 76.60%, Val Loss: 0.6118, Val Accuracy: 78.42%
# Epoch [69/100], Train Loss: 0.6261, Train Accuracy: 76.67%, Val Loss: 0.6078, Val Accuracy: 78.25%
# Epoch [70/100], Train Loss: 0.6239, Train Accuracy: 76.98%, Val Loss: 0.6066, Val Accuracy: 78.25%
# Epoch [71/100], Train Loss: 0.6217, Train Accuracy: 76.94%, Val Loss: 0.6037, Val Accuracy: 79.00%
# Epoch [72/100], Train Loss: 0.6196, Train Accuracy: 76.92%, Val Loss: 0.6025, Val Accuracy: 78.17%
# Epoch [73/100], Train Loss: 0.6175, Train Accuracy: 77.27%, Val Loss: 0.6010, Val Accuracy: 78.92%
# Epoch [74/100], Train Loss: 0.6152, Train Accuracy: 77.06%, Val Loss: 0.5997, Val Accuracy: 78.92%
# Epoch [75/100], Train Loss: 0.6132, Train Accuracy: 77.25%, Val Loss: 0.5992, Val Accuracy: 78.50%
# Epoch [76/100], Train Loss: 0.6110, Train Accuracy: 77.40%, Val Loss: 0.5967, Val Accuracy: 79.58%
# Epoch [77/100], Train Loss: 0.6093, Train Accuracy: 77.29%, Val Loss: 0.5953, Val Accuracy: 78.83%
# Epoch [78/100], Train Loss: 0.6073, Train Accuracy: 77.50%, Val Loss: 0.5945, Val Accuracy: 78.83%
# Epoch [79/100], Train Loss: 0.6053, Train Accuracy: 77.42%, Val Loss: 0.5919, Val Accuracy: 79.42%
# Epoch [80/100], Train Loss: 0.6034, Train Accuracy: 77.65%, Val Loss: 0.5908, Val Accuracy: 79.17%
# Epoch [81/100], Train Loss: 0.6015, Train Accuracy: 77.62%, Val Loss: 0.5907, Val Accuracy: 78.83%
# Epoch [82/100], Train Loss: 0.5994, Train Accuracy: 77.67%, Val Loss: 0.5881, Val Accuracy: 78.83%
# Epoch [83/100], Train Loss: 0.5980, Train Accuracy: 77.54%, Val Loss: 0.5873, Val Accuracy: 79.00%
# Epoch [84/100], Train Loss: 0.5959, Train Accuracy: 77.75%, Val Loss: 0.5863, Val Accuracy: 79.17%
# Epoch [85/100], Train Loss: 0.5942, Train Accuracy: 77.77%, Val Loss: 0.5835, Val Accuracy: 79.58%
# Epoch [86/100], Train Loss: 0.5923, Train Accuracy: 77.81%, Val Loss: 0.5838, Val Accuracy: 79.58%
# Epoch [87/100], Train Loss: 0.5906, Train Accuracy: 77.69%, Val Loss: 0.5817, Val Accuracy: 79.50%
# Epoch [88/100], Train Loss: 0.5887, Train Accuracy: 78.08%, Val Loss: 0.5807, Val Accuracy: 79.17%
# Epoch [89/100], Train Loss: 0.5870, Train Accuracy: 78.19%, Val Loss: 0.5781, Val Accuracy: 80.17%
# Epoch [90/100], Train Loss: 0.5853, Train Accuracy: 78.12%, Val Loss: 0.5799, Val Accuracy: 79.25%
# Epoch [91/100], Train Loss: 0.5838, Train Accuracy: 78.42%, Val Loss: 0.5775, Val Accuracy: 79.83%
# Epoch [92/100], Train Loss: 0.5823, Train Accuracy: 78.27%, Val Loss: 0.5759, Val Accuracy: 80.00%
# Epoch [93/100], Train Loss: 0.5805, Train Accuracy: 78.15%, Val Loss: 0.5740, Val Accuracy: 80.33%
# Epoch [94/100], Train Loss: 0.5787, Train Accuracy: 78.44%, Val Loss: 0.5733, Val Accuracy: 80.17%
# Epoch [95/100], Train Loss: 0.5773, Train Accuracy: 78.48%, Val Loss: 0.5719, Val Accuracy: 80.33%
# Epoch [96/100], Train Loss: 0.5752, Train Accuracy: 78.71%, Val Loss: 0.5734, Val Accuracy: 79.75%
# Epoch [97/100], Train Loss: 0.5742, Train Accuracy: 78.88%, Val Loss: 0.5692, Val Accuracy: 80.42%
# Epoch [98/100], Train Loss: 0.5729, Train Accuracy: 78.88%, Val Loss: 0.5692, Val Accuracy: 80.17%
# Epoch [99/100], Train Loss: 0.5714, Train Accuracy: 78.94%, Val Loss: 0.5685, Val Accuracy: 80.58%
# Epoch [100/100], Train Loss: 0.5698, Train Accuracy: 78.85%, Val Loss: 0.5671, Val Accuracy: 80.00%
# Model Training Time: 243.558 s
# Model Accutacy:78.21
# 11 100 small_random relu sgd None 0.0 start
# Epoch [1/100], Train Loss: 2.2334, Train Accuracy: 16.00%, Val Loss: 2.1538, Val Accuracy: 25.50%
# Epoch [2/100], Train Loss: 2.0996, Train Accuracy: 27.46%, Val Loss: 2.0371, Val Accuracy: 30.83%
# Epoch [3/100], Train Loss: 1.9946, Train Accuracy: 31.75%, Val Loss: 1.9359, Val Accuracy: 34.00%
# Epoch [4/100], Train Loss: 1.9007, Train Accuracy: 34.27%, Val Loss: 1.8416, Val Accuracy: 36.58%
# Epoch [5/100], Train Loss: 1.8117, Train Accuracy: 36.94%, Val Loss: 1.7514, Val Accuracy: 39.42%
# Epoch [6/100], Train Loss: 1.7266, Train Accuracy: 40.98%, Val Loss: 1.6657, Val Accuracy: 43.67%
# Epoch [7/100], Train Loss: 1.6456, Train Accuracy: 43.79%, Val Loss: 1.5841, Val Accuracy: 46.67%
# Epoch [8/100], Train Loss: 1.5658, Train Accuracy: 46.42%, Val Loss: 1.5012, Val Accuracy: 50.00%
# Epoch [9/100], Train Loss: 1.4868, Train Accuracy: 49.35%, Val Loss: 1.4229, Val Accuracy: 52.50%
# Epoch [10/100], Train Loss: 1.4108, Train Accuracy: 54.15%, Val Loss: 1.3480, Val Accuracy: 57.92%
# Epoch [11/100], Train Loss: 1.3379, Train Accuracy: 58.42%, Val Loss: 1.2774, Val Accuracy: 61.83%
# Epoch [12/100], Train Loss: 1.2686, Train Accuracy: 61.83%, Val Loss: 1.2114, Val Accuracy: 64.58%
# Epoch [13/100], Train Loss: 1.2045, Train Accuracy: 64.04%, Val Loss: 1.1525, Val Accuracy: 67.42%
# Epoch [14/100], Train Loss: 1.1469, Train Accuracy: 66.00%, Val Loss: 1.0999, Val Accuracy: 68.17%
# Epoch [15/100], Train Loss: 1.0962, Train Accuracy: 66.98%, Val Loss: 1.0537, Val Accuracy: 68.67%
# Epoch [16/100], Train Loss: 1.0522, Train Accuracy: 67.90%, Val Loss: 1.0138, Val Accuracy: 70.33%
# Epoch [17/100], Train Loss: 1.0136, Train Accuracy: 68.77%, Val Loss: 0.9782, Val Accuracy: 70.00%
# Epoch [18/100], Train Loss: 0.9794, Train Accuracy: 69.71%, Val Loss: 0.9469, Val Accuracy: 70.25%
# Epoch [19/100], Train Loss: 0.9497, Train Accuracy: 69.75%, Val Loss: 0.9206, Val Accuracy: 71.42%
# Epoch [20/100], Train Loss: 0.9234, Train Accuracy: 70.42%, Val Loss: 0.8944, Val Accuracy: 71.75%
# Epoch [21/100], Train Loss: 0.9000, Train Accuracy: 70.75%, Val Loss: 0.8728, Val Accuracy: 72.17%
# Epoch [22/100], Train Loss: 0.8793, Train Accuracy: 70.85%, Val Loss: 0.8533, Val Accuracy: 72.17%
# Epoch [23/100], Train Loss: 0.8609, Train Accuracy: 71.29%, Val Loss: 0.8355, Val Accuracy: 72.50%
# Epoch [24/100], Train Loss: 0.8440, Train Accuracy: 71.44%, Val Loss: 0.8215, Val Accuracy: 72.17%
# Epoch [25/100], Train Loss: 0.8293, Train Accuracy: 71.83%, Val Loss: 0.8048, Val Accuracy: 72.58%
# Epoch [26/100], Train Loss: 0.8158, Train Accuracy: 71.92%, Val Loss: 0.7921, Val Accuracy: 73.17%
# Epoch [27/100], Train Loss: 0.8033, Train Accuracy: 71.96%, Val Loss: 0.7803, Val Accuracy: 73.25%
# Epoch [28/100], Train Loss: 0.7916, Train Accuracy: 72.25%, Val Loss: 0.7692, Val Accuracy: 74.17%
# Epoch [29/100], Train Loss: 0.7808, Train Accuracy: 72.75%, Val Loss: 0.7593, Val Accuracy: 74.00%
# Epoch [30/100], Train Loss: 0.7713, Train Accuracy: 72.71%, Val Loss: 0.7516, Val Accuracy: 74.58%
# Epoch [31/100], Train Loss: 0.7622, Train Accuracy: 73.06%, Val Loss: 0.7423, Val Accuracy: 74.67%
# Epoch [32/100], Train Loss: 0.7536, Train Accuracy: 73.12%, Val Loss: 0.7346, Val Accuracy: 75.00%
# Epoch [33/100], Train Loss: 0.7461, Train Accuracy: 73.40%, Val Loss: 0.7253, Val Accuracy: 75.33%
# Epoch [34/100], Train Loss: 0.7387, Train Accuracy: 73.48%, Val Loss: 0.7183, Val Accuracy: 75.58%
# Epoch [35/100], Train Loss: 0.7320, Train Accuracy: 73.60%, Val Loss: 0.7115, Val Accuracy: 75.58%
# Epoch [36/100], Train Loss: 0.7257, Train Accuracy: 73.75%, Val Loss: 0.7062, Val Accuracy: 75.67%
# Epoch [37/100], Train Loss: 0.7194, Train Accuracy: 74.35%, Val Loss: 0.7000, Val Accuracy: 75.75%
# Epoch [38/100], Train Loss: 0.7134, Train Accuracy: 74.42%, Val Loss: 0.6958, Val Accuracy: 75.67%
# Epoch [39/100], Train Loss: 0.7077, Train Accuracy: 74.38%, Val Loss: 0.6902, Val Accuracy: 75.67%
# Epoch [40/100], Train Loss: 0.7025, Train Accuracy: 74.77%, Val Loss: 0.6851, Val Accuracy: 75.75%
# Epoch [41/100], Train Loss: 0.6975, Train Accuracy: 74.98%, Val Loss: 0.6814, Val Accuracy: 76.00%
# Epoch [42/100], Train Loss: 0.6927, Train Accuracy: 74.85%, Val Loss: 0.6761, Val Accuracy: 76.17%
# Epoch [43/100], Train Loss: 0.6879, Train Accuracy: 75.21%, Val Loss: 0.6722, Val Accuracy: 76.08%
# Epoch [44/100], Train Loss: 0.6835, Train Accuracy: 75.02%, Val Loss: 0.6670, Val Accuracy: 76.33%
# Epoch [45/100], Train Loss: 0.6793, Train Accuracy: 75.23%, Val Loss: 0.6633, Val Accuracy: 76.50%
# Epoch [46/100], Train Loss: 0.6751, Train Accuracy: 75.69%, Val Loss: 0.6610, Val Accuracy: 76.50%
# Epoch [47/100], Train Loss: 0.6711, Train Accuracy: 75.31%, Val Loss: 0.6580, Val Accuracy: 76.67%
# Epoch [48/100], Train Loss: 0.6672, Train Accuracy: 75.83%, Val Loss: 0.6539, Val Accuracy: 76.92%
# Epoch [49/100], Train Loss: 0.6634, Train Accuracy: 75.94%, Val Loss: 0.6511, Val Accuracy: 76.58%
# Epoch [50/100], Train Loss: 0.6597, Train Accuracy: 75.98%, Val Loss: 0.6470, Val Accuracy: 76.50%
# Epoch [51/100], Train Loss: 0.6562, Train Accuracy: 75.90%, Val Loss: 0.6423, Val Accuracy: 76.83%
# Epoch [52/100], Train Loss: 0.6526, Train Accuracy: 76.33%, Val Loss: 0.6411, Val Accuracy: 76.92%
# Epoch [53/100], Train Loss: 0.6489, Train Accuracy: 76.17%, Val Loss: 0.6383, Val Accuracy: 77.00%
# Epoch [54/100], Train Loss: 0.6457, Train Accuracy: 76.35%, Val Loss: 0.6349, Val Accuracy: 77.42%
# Epoch [55/100], Train Loss: 0.6428, Train Accuracy: 76.50%, Val Loss: 0.6311, Val Accuracy: 77.67%
# Epoch [56/100], Train Loss: 0.6397, Train Accuracy: 76.79%, Val Loss: 0.6289, Val Accuracy: 77.33%
# Epoch [57/100], Train Loss: 0.6366, Train Accuracy: 76.90%, Val Loss: 0.6282, Val Accuracy: 77.33%
# Epoch [58/100], Train Loss: 0.6335, Train Accuracy: 77.08%, Val Loss: 0.6227, Val Accuracy: 77.75%
# Epoch [59/100], Train Loss: 0.6304, Train Accuracy: 77.08%, Val Loss: 0.6211, Val Accuracy: 77.58%
# Epoch [60/100], Train Loss: 0.6275, Train Accuracy: 77.15%, Val Loss: 0.6193, Val Accuracy: 77.92%
# Epoch [61/100], Train Loss: 0.6250, Train Accuracy: 77.46%, Val Loss: 0.6158, Val Accuracy: 77.75%
# Epoch [62/100], Train Loss: 0.6223, Train Accuracy: 77.23%, Val Loss: 0.6142, Val Accuracy: 78.25%
# Epoch [63/100], Train Loss: 0.6196, Train Accuracy: 77.50%, Val Loss: 0.6130, Val Accuracy: 77.92%
# Epoch [64/100], Train Loss: 0.6172, Train Accuracy: 77.46%, Val Loss: 0.6090, Val Accuracy: 78.83%
# Epoch [65/100], Train Loss: 0.6145, Train Accuracy: 77.77%, Val Loss: 0.6080, Val Accuracy: 78.08%
# Epoch [66/100], Train Loss: 0.6119, Train Accuracy: 77.67%, Val Loss: 0.6067, Val Accuracy: 78.17%
# Epoch [67/100], Train Loss: 0.6094, Train Accuracy: 77.92%, Val Loss: 0.6029, Val Accuracy: 78.75%
# Epoch [68/100], Train Loss: 0.6071, Train Accuracy: 77.83%, Val Loss: 0.6008, Val Accuracy: 79.17%
# Epoch [69/100], Train Loss: 0.6044, Train Accuracy: 78.23%, Val Loss: 0.6006, Val Accuracy: 78.67%
# Epoch [70/100], Train Loss: 0.6022, Train Accuracy: 77.96%, Val Loss: 0.5980, Val Accuracy: 79.00%
# Epoch [71/100], Train Loss: 0.5994, Train Accuracy: 78.19%, Val Loss: 0.5965, Val Accuracy: 78.58%
# Epoch [72/100], Train Loss: 0.5976, Train Accuracy: 78.38%, Val Loss: 0.5944, Val Accuracy: 79.25%
# Epoch [73/100], Train Loss: 0.5950, Train Accuracy: 78.40%, Val Loss: 0.5912, Val Accuracy: 79.42%
# Epoch [74/100], Train Loss: 0.5930, Train Accuracy: 78.50%, Val Loss: 0.5913, Val Accuracy: 79.25%
# Epoch [75/100], Train Loss: 0.5912, Train Accuracy: 78.65%, Val Loss: 0.5895, Val Accuracy: 79.42%
# Epoch [76/100], Train Loss: 0.5885, Train Accuracy: 78.52%, Val Loss: 0.5871, Val Accuracy: 79.33%
# Epoch [77/100], Train Loss: 0.5867, Train Accuracy: 78.71%, Val Loss: 0.5859, Val Accuracy: 79.58%
# Epoch [78/100], Train Loss: 0.5846, Train Accuracy: 79.04%, Val Loss: 0.5840, Val Accuracy: 79.75%
# Epoch [79/100], Train Loss: 0.5824, Train Accuracy: 78.90%, Val Loss: 0.5823, Val Accuracy: 79.92%
# Epoch [80/100], Train Loss: 0.5805, Train Accuracy: 79.08%, Val Loss: 0.5808, Val Accuracy: 79.83%
# Epoch [81/100], Train Loss: 0.5784, Train Accuracy: 78.90%, Val Loss: 0.5801, Val Accuracy: 79.83%
# Epoch [82/100], Train Loss: 0.5765, Train Accuracy: 79.12%, Val Loss: 0.5765, Val Accuracy: 80.17%
# Epoch [83/100], Train Loss: 0.5744, Train Accuracy: 79.25%, Val Loss: 0.5747, Val Accuracy: 80.00%
# Epoch [84/100], Train Loss: 0.5728, Train Accuracy: 79.21%, Val Loss: 0.5735, Val Accuracy: 80.08%
# Epoch [85/100], Train Loss: 0.5704, Train Accuracy: 79.54%, Val Loss: 0.5743, Val Accuracy: 80.50%
# Epoch [86/100], Train Loss: 0.5686, Train Accuracy: 79.54%, Val Loss: 0.5730, Val Accuracy: 79.83%
# Epoch [87/100], Train Loss: 0.5672, Train Accuracy: 79.44%, Val Loss: 0.5686, Val Accuracy: 80.25%
# Epoch [88/100], Train Loss: 0.5652, Train Accuracy: 79.67%, Val Loss: 0.5694, Val Accuracy: 80.67%
# Epoch [89/100], Train Loss: 0.5636, Train Accuracy: 79.33%, Val Loss: 0.5667, Val Accuracy: 80.33%
# Epoch [90/100], Train Loss: 0.5617, Train Accuracy: 79.71%, Val Loss: 0.5643, Val Accuracy: 80.33%
# Epoch [91/100], Train Loss: 0.5602, Train Accuracy: 79.65%, Val Loss: 0.5633, Val Accuracy: 80.42%
# Epoch [92/100], Train Loss: 0.5581, Train Accuracy: 79.96%, Val Loss: 0.5641, Val Accuracy: 80.58%
# Epoch [93/100], Train Loss: 0.5567, Train Accuracy: 80.02%, Val Loss: 0.5619, Val Accuracy: 80.50%
# Epoch [94/100], Train Loss: 0.5548, Train Accuracy: 80.15%, Val Loss: 0.5605, Val Accuracy: 80.50%
# Epoch [95/100], Train Loss: 0.5531, Train Accuracy: 80.10%, Val Loss: 0.5604, Val Accuracy: 80.58%
# Epoch [96/100], Train Loss: 0.5515, Train Accuracy: 80.40%, Val Loss: 0.5580, Val Accuracy: 80.33%
# Epoch [97/100], Train Loss: 0.5497, Train Accuracy: 79.98%, Val Loss: 0.5553, Val Accuracy: 80.67%
# Epoch [98/100], Train Loss: 0.5482, Train Accuracy: 80.46%, Val Loss: 0.5558, Val Accuracy: 80.75%
# Epoch [99/100], Train Loss: 0.5466, Train Accuracy: 80.17%, Val Loss: 0.5548, Val Accuracy: 80.42%
# Epoch [100/100], Train Loss: 0.5449, Train Accuracy: 80.46%, Val Loss: 0.5539, Val Accuracy: 80.92%
# Model Training Time: 253.573 s
# Model Accutacy:78.97
# 11 200 small_random relu sgd None 0.0 start
# Epoch [1/200], Train Loss: 2.2353, Train Accuracy: 23.17%, Val Loss: 2.1358, Val Accuracy: 26.75%
# Epoch [2/200], Train Loss: 2.0485, Train Accuracy: 29.62%, Val Loss: 1.9590, Val Accuracy: 38.25%
# Epoch [3/200], Train Loss: 1.8920, Train Accuracy: 40.79%, Val Loss: 1.8196, Val Accuracy: 40.92%
# Epoch [4/200], Train Loss: 1.7613, Train Accuracy: 42.10%, Val Loss: 1.6965, Val Accuracy: 44.17%
# Epoch [5/200], Train Loss: 1.6439, Train Accuracy: 45.65%, Val Loss: 1.5820, Val Accuracy: 48.17%
# Epoch [6/200], Train Loss: 1.5317, Train Accuracy: 51.00%, Val Loss: 1.4690, Val Accuracy: 53.25%
# Epoch [7/200], Train Loss: 1.4281, Train Accuracy: 55.98%, Val Loss: 1.3716, Val Accuracy: 59.25%
# Epoch [8/200], Train Loss: 1.3407, Train Accuracy: 60.85%, Val Loss: 1.2903, Val Accuracy: 64.17%
# Epoch [9/200], Train Loss: 1.2678, Train Accuracy: 64.50%, Val Loss: 1.2234, Val Accuracy: 68.08%
# Epoch [10/200], Train Loss: 1.2072, Train Accuracy: 65.90%, Val Loss: 1.1670, Val Accuracy: 69.67%
# Epoch [11/200], Train Loss: 1.1559, Train Accuracy: 66.94%, Val Loss: 1.1202, Val Accuracy: 69.92%
# Epoch [12/200], Train Loss: 1.1123, Train Accuracy: 68.62%, Val Loss: 1.0773, Val Accuracy: 70.75%
# Epoch [13/200], Train Loss: 1.0740, Train Accuracy: 69.06%, Val Loss: 1.0422, Val Accuracy: 71.42%
# Epoch [14/200], Train Loss: 1.0397, Train Accuracy: 69.56%, Val Loss: 1.0090, Val Accuracy: 71.58%
# Epoch [15/200], Train Loss: 1.0089, Train Accuracy: 70.27%, Val Loss: 0.9798, Val Accuracy: 72.08%
# Epoch [16/200], Train Loss: 0.9811, Train Accuracy: 70.54%, Val Loss: 0.9535, Val Accuracy: 72.17%
# Epoch [17/200], Train Loss: 0.9557, Train Accuracy: 71.31%, Val Loss: 0.9287, Val Accuracy: 72.75%
# Epoch [18/200], Train Loss: 0.9327, Train Accuracy: 71.19%, Val Loss: 0.9066, Val Accuracy: 72.83%
# Epoch [19/200], Train Loss: 0.9120, Train Accuracy: 71.48%, Val Loss: 0.8865, Val Accuracy: 73.00%
# Epoch [20/200], Train Loss: 0.8930, Train Accuracy: 71.94%, Val Loss: 0.8688, Val Accuracy: 72.83%
# Epoch [21/200], Train Loss: 0.8754, Train Accuracy: 72.06%, Val Loss: 0.8514, Val Accuracy: 73.75%
# Epoch [22/200], Train Loss: 0.8592, Train Accuracy: 72.38%, Val Loss: 0.8342, Val Accuracy: 74.17%
# Epoch [23/200], Train Loss: 0.8444, Train Accuracy: 72.48%, Val Loss: 0.8205, Val Accuracy: 74.08%
# Epoch [24/200], Train Loss: 0.8309, Train Accuracy: 72.58%, Val Loss: 0.8069, Val Accuracy: 74.50%
# Epoch [25/200], Train Loss: 0.8185, Train Accuracy: 72.85%, Val Loss: 0.7943, Val Accuracy: 74.25%
# Epoch [26/200], Train Loss: 0.8067, Train Accuracy: 72.88%, Val Loss: 0.7822, Val Accuracy: 75.17%
# Epoch [27/200], Train Loss: 0.7954, Train Accuracy: 73.15%, Val Loss: 0.7712, Val Accuracy: 75.33%
# Epoch [28/200], Train Loss: 0.7852, Train Accuracy: 73.52%, Val Loss: 0.7607, Val Accuracy: 75.17%
# Epoch [29/200], Train Loss: 0.7756, Train Accuracy: 73.79%, Val Loss: 0.7524, Val Accuracy: 74.67%
# Epoch [30/200], Train Loss: 0.7667, Train Accuracy: 74.08%, Val Loss: 0.7428, Val Accuracy: 76.08%
# Epoch [31/200], Train Loss: 0.7579, Train Accuracy: 74.15%, Val Loss: 0.7347, Val Accuracy: 76.08%
# Epoch [32/200], Train Loss: 0.7499, Train Accuracy: 74.25%, Val Loss: 0.7247, Val Accuracy: 76.58%
# Epoch [33/200], Train Loss: 0.7422, Train Accuracy: 74.60%, Val Loss: 0.7176, Val Accuracy: 76.42%
# Epoch [34/200], Train Loss: 0.7348, Train Accuracy: 74.48%, Val Loss: 0.7131, Val Accuracy: 75.83%
# Epoch [35/200], Train Loss: 0.7284, Train Accuracy: 74.67%, Val Loss: 0.7043, Val Accuracy: 76.75%
# Epoch [36/200], Train Loss: 0.7215, Train Accuracy: 74.88%, Val Loss: 0.6990, Val Accuracy: 76.17%
# Epoch [37/200], Train Loss: 0.7154, Train Accuracy: 75.00%, Val Loss: 0.6939, Val Accuracy: 76.50%
# Epoch [38/200], Train Loss: 0.7095, Train Accuracy: 75.19%, Val Loss: 0.6872, Val Accuracy: 76.92%
# Epoch [39/200], Train Loss: 0.7041, Train Accuracy: 75.62%, Val Loss: 0.6823, Val Accuracy: 76.75%
# Epoch [40/200], Train Loss: 0.6988, Train Accuracy: 75.52%, Val Loss: 0.6760, Val Accuracy: 77.17%
# Epoch [41/200], Train Loss: 0.6936, Train Accuracy: 75.62%, Val Loss: 0.6720, Val Accuracy: 77.08%
# Epoch [42/200], Train Loss: 0.6886, Train Accuracy: 75.67%, Val Loss: 0.6665, Val Accuracy: 77.08%
# Epoch [43/200], Train Loss: 0.6837, Train Accuracy: 75.77%, Val Loss: 0.6623, Val Accuracy: 77.00%
# Epoch [44/200], Train Loss: 0.6792, Train Accuracy: 75.75%, Val Loss: 0.6578, Val Accuracy: 78.17%
# Epoch [45/200], Train Loss: 0.6750, Train Accuracy: 76.17%, Val Loss: 0.6561, Val Accuracy: 77.25%
# Epoch [46/200], Train Loss: 0.6708, Train Accuracy: 76.15%, Val Loss: 0.6495, Val Accuracy: 77.75%
# Epoch [47/200], Train Loss: 0.6664, Train Accuracy: 76.58%, Val Loss: 0.6474, Val Accuracy: 77.42%
# Epoch [48/200], Train Loss: 0.6626, Train Accuracy: 76.58%, Val Loss: 0.6413, Val Accuracy: 78.42%
# Epoch [49/200], Train Loss: 0.6585, Train Accuracy: 76.48%, Val Loss: 0.6391, Val Accuracy: 78.17%
# Epoch [50/200], Train Loss: 0.6549, Train Accuracy: 76.46%, Val Loss: 0.6354, Val Accuracy: 78.08%
# Epoch [51/200], Train Loss: 0.6513, Train Accuracy: 76.81%, Val Loss: 0.6307, Val Accuracy: 78.67%
# Epoch [52/200], Train Loss: 0.6475, Train Accuracy: 77.17%, Val Loss: 0.6295, Val Accuracy: 78.08%
# Epoch [53/200], Train Loss: 0.6440, Train Accuracy: 76.83%, Val Loss: 0.6253, Val Accuracy: 79.17%
# Epoch [54/200], Train Loss: 0.6407, Train Accuracy: 77.08%, Val Loss: 0.6227, Val Accuracy: 78.33%
# Epoch [55/200], Train Loss: 0.6376, Train Accuracy: 77.25%, Val Loss: 0.6206, Val Accuracy: 78.50%
# Epoch [56/200], Train Loss: 0.6345, Train Accuracy: 77.38%, Val Loss: 0.6165, Val Accuracy: 78.75%
# Epoch [57/200], Train Loss: 0.6310, Train Accuracy: 77.46%, Val Loss: 0.6139, Val Accuracy: 79.00%
# Epoch [58/200], Train Loss: 0.6281, Train Accuracy: 77.62%, Val Loss: 0.6134, Val Accuracy: 78.17%
# Epoch [59/200], Train Loss: 0.6254, Train Accuracy: 77.50%, Val Loss: 0.6108, Val Accuracy: 78.58%
# Epoch [60/200], Train Loss: 0.6226, Train Accuracy: 77.67%, Val Loss: 0.6074, Val Accuracy: 79.33%
# Epoch [61/200], Train Loss: 0.6195, Train Accuracy: 77.81%, Val Loss: 0.6024, Val Accuracy: 79.25%
# Epoch [62/200], Train Loss: 0.6166, Train Accuracy: 77.85%, Val Loss: 0.6034, Val Accuracy: 79.00%
# Epoch [63/200], Train Loss: 0.6137, Train Accuracy: 78.21%, Val Loss: 0.5988, Val Accuracy: 78.92%
# Epoch [64/200], Train Loss: 0.6115, Train Accuracy: 78.10%, Val Loss: 0.5980, Val Accuracy: 78.92%
# Epoch [65/200], Train Loss: 0.6086, Train Accuracy: 78.21%, Val Loss: 0.5981, Val Accuracy: 78.33%
# Epoch [66/200], Train Loss: 0.6059, Train Accuracy: 77.83%, Val Loss: 0.5929, Val Accuracy: 79.83%
# Epoch [67/200], Train Loss: 0.6036, Train Accuracy: 78.58%, Val Loss: 0.5925, Val Accuracy: 79.42%
# Epoch [68/200], Train Loss: 0.6010, Train Accuracy: 78.35%, Val Loss: 0.5898, Val Accuracy: 79.92%
# Epoch [69/200], Train Loss: 0.5985, Train Accuracy: 78.35%, Val Loss: 0.5890, Val Accuracy: 79.00%
# Epoch [70/200], Train Loss: 0.5965, Train Accuracy: 78.38%, Val Loss: 0.5870, Val Accuracy: 79.58%
# Epoch [71/200], Train Loss: 0.5939, Train Accuracy: 78.56%, Val Loss: 0.5828, Val Accuracy: 80.08%
# Epoch [72/200], Train Loss: 0.5914, Train Accuracy: 78.77%, Val Loss: 0.5833, Val Accuracy: 80.08%
# Epoch [73/200], Train Loss: 0.5896, Train Accuracy: 78.90%, Val Loss: 0.5809, Val Accuracy: 79.83%
# Epoch [74/200], Train Loss: 0.5875, Train Accuracy: 78.77%, Val Loss: 0.5784, Val Accuracy: 80.08%
# Epoch [75/200], Train Loss: 0.5850, Train Accuracy: 79.08%, Val Loss: 0.5760, Val Accuracy: 80.50%
# Epoch [76/200], Train Loss: 0.5827, Train Accuracy: 79.10%, Val Loss: 0.5721, Val Accuracy: 80.42%
# Epoch [77/200], Train Loss: 0.5810, Train Accuracy: 78.94%, Val Loss: 0.5719, Val Accuracy: 80.58%
# Epoch [78/200], Train Loss: 0.5786, Train Accuracy: 79.15%, Val Loss: 0.5705, Val Accuracy: 80.58%
# Epoch [79/200], Train Loss: 0.5769, Train Accuracy: 79.40%, Val Loss: 0.5694, Val Accuracy: 80.67%
# Epoch [80/200], Train Loss: 0.5744, Train Accuracy: 79.44%, Val Loss: 0.5664, Val Accuracy: 81.17%
# Epoch [81/200], Train Loss: 0.5729, Train Accuracy: 79.29%, Val Loss: 0.5652, Val Accuracy: 81.00%
# Epoch [82/200], Train Loss: 0.5709, Train Accuracy: 79.40%, Val Loss: 0.5648, Val Accuracy: 80.83%
# Epoch [83/200], Train Loss: 0.5692, Train Accuracy: 79.50%, Val Loss: 0.5624, Val Accuracy: 81.08%
# Epoch [84/200], Train Loss: 0.5670, Train Accuracy: 79.85%, Val Loss: 0.5611, Val Accuracy: 80.92%
# Epoch [85/200], Train Loss: 0.5652, Train Accuracy: 79.65%, Val Loss: 0.5591, Val Accuracy: 81.00%
# Epoch [86/200], Train Loss: 0.5635, Train Accuracy: 79.81%, Val Loss: 0.5577, Val Accuracy: 81.25%
# Epoch [87/200], Train Loss: 0.5615, Train Accuracy: 80.02%, Val Loss: 0.5553, Val Accuracy: 81.17%
# Epoch [88/200], Train Loss: 0.5598, Train Accuracy: 79.88%, Val Loss: 0.5575, Val Accuracy: 81.17%
# Epoch [89/200], Train Loss: 0.5583, Train Accuracy: 79.90%, Val Loss: 0.5563, Val Accuracy: 80.92%
# Epoch [90/200], Train Loss: 0.5564, Train Accuracy: 79.92%, Val Loss: 0.5547, Val Accuracy: 81.25%
# Epoch [91/200], Train Loss: 0.5547, Train Accuracy: 80.15%, Val Loss: 0.5554, Val Accuracy: 81.58%
# Epoch [92/200], Train Loss: 0.5528, Train Accuracy: 80.08%, Val Loss: 0.5508, Val Accuracy: 81.17%
# Epoch [93/200], Train Loss: 0.5515, Train Accuracy: 80.40%, Val Loss: 0.5523, Val Accuracy: 81.58%
# Epoch [94/200], Train Loss: 0.5500, Train Accuracy: 80.46%, Val Loss: 0.5492, Val Accuracy: 81.25%
# Epoch [95/200], Train Loss: 0.5482, Train Accuracy: 80.15%, Val Loss: 0.5472, Val Accuracy: 80.92%
# Epoch [96/200], Train Loss: 0.5469, Train Accuracy: 80.38%, Val Loss: 0.5454, Val Accuracy: 81.42%
# Epoch [97/200], Train Loss: 0.5450, Train Accuracy: 80.69%, Val Loss: 0.5448, Val Accuracy: 81.83%
# Epoch [98/200], Train Loss: 0.5433, Train Accuracy: 80.65%, Val Loss: 0.5449, Val Accuracy: 81.42%
# Epoch [99/200], Train Loss: 0.5417, Train Accuracy: 80.69%, Val Loss: 0.5412, Val Accuracy: 81.42%
# Epoch [100/200], Train Loss: 0.5404, Train Accuracy: 80.69%, Val Loss: 0.5457, Val Accuracy: 81.67%
# Epoch [101/200], Train Loss: 0.5392, Train Accuracy: 80.85%, Val Loss: 0.5421, Val Accuracy: 81.75%
# Epoch [102/200], Train Loss: 0.5377, Train Accuracy: 80.81%, Val Loss: 0.5424, Val Accuracy: 81.33%
# Epoch [103/200], Train Loss: 0.5365, Train Accuracy: 80.94%, Val Loss: 0.5414, Val Accuracy: 81.17%
# Epoch [104/200], Train Loss: 0.5349, Train Accuracy: 81.12%, Val Loss: 0.5396, Val Accuracy: 81.75%
# Epoch [105/200], Train Loss: 0.5337, Train Accuracy: 80.90%, Val Loss: 0.5380, Val Accuracy: 81.50%
# Epoch [106/200], Train Loss: 0.5321, Train Accuracy: 80.96%, Val Loss: 0.5369, Val Accuracy: 81.75%
# Epoch [107/200], Train Loss: 0.5309, Train Accuracy: 80.85%, Val Loss: 0.5376, Val Accuracy: 81.50%
# Epoch [108/200], Train Loss: 0.5296, Train Accuracy: 81.12%, Val Loss: 0.5355, Val Accuracy: 81.50%
# Epoch [109/200], Train Loss: 0.5276, Train Accuracy: 80.92%, Val Loss: 0.5370, Val Accuracy: 81.25%
# Epoch [110/200], Train Loss: 0.5270, Train Accuracy: 81.17%, Val Loss: 0.5334, Val Accuracy: 82.25%
# Epoch [111/200], Train Loss: 0.5256, Train Accuracy: 81.08%, Val Loss: 0.5356, Val Accuracy: 81.17%
# Epoch [112/200], Train Loss: 0.5240, Train Accuracy: 81.02%, Val Loss: 0.5322, Val Accuracy: 81.50%
# Epoch [113/200], Train Loss: 0.5227, Train Accuracy: 81.10%, Val Loss: 0.5355, Val Accuracy: 81.42%
# Epoch [114/200], Train Loss: 0.5218, Train Accuracy: 81.21%, Val Loss: 0.5307, Val Accuracy: 81.58%
# Epoch [115/200], Train Loss: 0.5197, Train Accuracy: 81.42%, Val Loss: 0.5339, Val Accuracy: 82.00%
# Epoch [116/200], Train Loss: 0.5194, Train Accuracy: 81.21%, Val Loss: 0.5299, Val Accuracy: 81.67%
# Epoch [117/200], Train Loss: 0.5178, Train Accuracy: 81.31%, Val Loss: 0.5269, Val Accuracy: 81.50%
# Epoch [118/200], Train Loss: 0.5168, Train Accuracy: 81.35%, Val Loss: 0.5281, Val Accuracy: 81.75%
# Epoch [119/200], Train Loss: 0.5159, Train Accuracy: 81.27%, Val Loss: 0.5249, Val Accuracy: 82.00%
# Epoch [120/200], Train Loss: 0.5145, Train Accuracy: 81.60%, Val Loss: 0.5272, Val Accuracy: 81.42%
# Epoch [121/200], Train Loss: 0.5135, Train Accuracy: 81.33%, Val Loss: 0.5227, Val Accuracy: 81.75%
# Epoch [122/200], Train Loss: 0.5122, Train Accuracy: 81.54%, Val Loss: 0.5230, Val Accuracy: 82.08%
# Epoch [123/200], Train Loss: 0.5109, Train Accuracy: 81.54%, Val Loss: 0.5252, Val Accuracy: 82.08%
# Epoch [124/200], Train Loss: 0.5098, Train Accuracy: 81.48%, Val Loss: 0.5215, Val Accuracy: 81.75%
# Epoch [125/200], Train Loss: 0.5090, Train Accuracy: 81.50%, Val Loss: 0.5208, Val Accuracy: 81.33%
# Epoch [126/200], Train Loss: 0.5080, Train Accuracy: 81.62%, Val Loss: 0.5211, Val Accuracy: 81.58%
# Epoch [127/200], Train Loss: 0.5067, Train Accuracy: 81.71%, Val Loss: 0.5230, Val Accuracy: 81.42%
# Epoch [128/200], Train Loss: 0.5053, Train Accuracy: 81.75%, Val Loss: 0.5224, Val Accuracy: 81.67%
# Epoch [129/200], Train Loss: 0.5047, Train Accuracy: 81.62%, Val Loss: 0.5203, Val Accuracy: 81.17%
# Epoch [130/200], Train Loss: 0.5037, Train Accuracy: 81.54%, Val Loss: 0.5185, Val Accuracy: 81.50%
# Epoch [131/200], Train Loss: 0.5022, Train Accuracy: 81.85%, Val Loss: 0.5228, Val Accuracy: 81.58%
# Epoch [132/200], Train Loss: 0.5017, Train Accuracy: 81.75%, Val Loss: 0.5202, Val Accuracy: 81.75%
# Epoch [133/200], Train Loss: 0.5005, Train Accuracy: 81.54%, Val Loss: 0.5206, Val Accuracy: 82.00%
# Epoch [134/200], Train Loss: 0.4994, Train Accuracy: 81.88%, Val Loss: 0.5200, Val Accuracy: 81.75%
# Epoch [135/200], Train Loss: 0.4984, Train Accuracy: 81.92%, Val Loss: 0.5147, Val Accuracy: 81.67%
# Epoch [136/200], Train Loss: 0.4971, Train Accuracy: 81.83%, Val Loss: 0.5180, Val Accuracy: 81.75%
# Epoch [137/200], Train Loss: 0.4962, Train Accuracy: 82.00%, Val Loss: 0.5134, Val Accuracy: 82.42%
# Epoch [138/200], Train Loss: 0.4952, Train Accuracy: 81.79%, Val Loss: 0.5175, Val Accuracy: 82.08%
# Epoch [139/200], Train Loss: 0.4947, Train Accuracy: 81.94%, Val Loss: 0.5162, Val Accuracy: 82.00%
# Epoch [140/200], Train Loss: 0.4938, Train Accuracy: 82.08%, Val Loss: 0.5144, Val Accuracy: 82.08%
# Epoch [141/200], Train Loss: 0.4928, Train Accuracy: 82.02%, Val Loss: 0.5140, Val Accuracy: 81.92%
# Epoch [142/200], Train Loss: 0.4917, Train Accuracy: 81.98%, Val Loss: 0.5110, Val Accuracy: 81.58%
# Epoch [143/200], Train Loss: 0.4908, Train Accuracy: 81.92%, Val Loss: 0.5119, Val Accuracy: 82.00%
# Epoch [144/200], Train Loss: 0.4897, Train Accuracy: 82.15%, Val Loss: 0.5110, Val Accuracy: 82.00%
# Epoch [145/200], Train Loss: 0.4889, Train Accuracy: 82.00%, Val Loss: 0.5121, Val Accuracy: 81.75%
# Epoch [146/200], Train Loss: 0.4882, Train Accuracy: 82.10%, Val Loss: 0.5101, Val Accuracy: 81.75%
# Epoch [147/200], Train Loss: 0.4872, Train Accuracy: 82.17%, Val Loss: 0.5098, Val Accuracy: 81.75%
# Epoch [148/200], Train Loss: 0.4863, Train Accuracy: 82.12%, Val Loss: 0.5102, Val Accuracy: 82.00%
# Epoch [149/200], Train Loss: 0.4851, Train Accuracy: 82.21%, Val Loss: 0.5114, Val Accuracy: 82.00%
# Epoch [150/200], Train Loss: 0.4845, Train Accuracy: 82.17%, Val Loss: 0.5105, Val Accuracy: 82.33%
# Epoch [151/200], Train Loss: 0.4835, Train Accuracy: 82.27%, Val Loss: 0.5110, Val Accuracy: 82.00%
# Epoch [152/200], Train Loss: 0.4829, Train Accuracy: 82.38%, Val Loss: 0.5100, Val Accuracy: 82.00%
# Epoch [153/200], Train Loss: 0.4819, Train Accuracy: 82.40%, Val Loss: 0.5067, Val Accuracy: 82.00%
# Epoch [154/200], Train Loss: 0.4811, Train Accuracy: 82.33%, Val Loss: 0.5083, Val Accuracy: 81.75%
# Epoch [155/200], Train Loss: 0.4804, Train Accuracy: 82.46%, Val Loss: 0.5071, Val Accuracy: 81.83%
# Epoch [156/200], Train Loss: 0.4793, Train Accuracy: 82.31%, Val Loss: 0.5086, Val Accuracy: 81.75%
# Epoch [157/200], Train Loss: 0.4788, Train Accuracy: 82.46%, Val Loss: 0.5071, Val Accuracy: 82.25%
# Epoch [158/200], Train Loss: 0.4777, Train Accuracy: 82.50%, Val Loss: 0.5064, Val Accuracy: 82.17%
# Epoch [159/200], Train Loss: 0.4769, Train Accuracy: 82.48%, Val Loss: 0.5060, Val Accuracy: 82.08%
# Epoch [160/200], Train Loss: 0.4757, Train Accuracy: 82.77%, Val Loss: 0.5081, Val Accuracy: 82.08%
# Epoch [161/200], Train Loss: 0.4748, Train Accuracy: 82.52%, Val Loss: 0.5053, Val Accuracy: 82.58%
# Epoch [162/200], Train Loss: 0.4747, Train Accuracy: 82.71%, Val Loss: 0.5053, Val Accuracy: 82.50%
# Epoch [163/200], Train Loss: 0.4735, Train Accuracy: 82.73%, Val Loss: 0.5031, Val Accuracy: 82.33%
# Epoch [164/200], Train Loss: 0.4724, Train Accuracy: 82.46%, Val Loss: 0.5039, Val Accuracy: 82.67%
# Epoch [165/200], Train Loss: 0.4722, Train Accuracy: 82.58%, Val Loss: 0.5017, Val Accuracy: 82.83%
# Epoch [166/200], Train Loss: 0.4713, Train Accuracy: 82.65%, Val Loss: 0.5048, Val Accuracy: 82.08%
# Epoch [167/200], Train Loss: 0.4701, Train Accuracy: 82.77%, Val Loss: 0.5057, Val Accuracy: 82.50%
# Epoch [168/200], Train Loss: 0.4692, Train Accuracy: 82.65%, Val Loss: 0.5045, Val Accuracy: 82.08%
# Epoch [169/200], Train Loss: 0.4689, Train Accuracy: 82.88%, Val Loss: 0.5030, Val Accuracy: 82.42%
# Epoch [170/200], Train Loss: 0.4679, Train Accuracy: 82.98%, Val Loss: 0.5040, Val Accuracy: 82.42%
# Epoch [171/200], Train Loss: 0.4675, Train Accuracy: 83.04%, Val Loss: 0.5031, Val Accuracy: 82.67%
# Epoch [172/200], Train Loss: 0.4667, Train Accuracy: 83.15%, Val Loss: 0.5016, Val Accuracy: 82.58%
# Epoch [173/200], Train Loss: 0.4658, Train Accuracy: 82.96%, Val Loss: 0.5015, Val Accuracy: 82.75%
# Epoch [174/200], Train Loss: 0.4646, Train Accuracy: 83.17%, Val Loss: 0.5015, Val Accuracy: 82.83%
# Epoch [175/200], Train Loss: 0.4644, Train Accuracy: 83.15%, Val Loss: 0.4990, Val Accuracy: 82.83%
# Epoch [176/200], Train Loss: 0.4634, Train Accuracy: 83.23%, Val Loss: 0.5020, Val Accuracy: 82.67%
# Epoch [177/200], Train Loss: 0.4625, Train Accuracy: 83.06%, Val Loss: 0.5028, Val Accuracy: 82.58%
# Epoch [178/200], Train Loss: 0.4621, Train Accuracy: 83.23%, Val Loss: 0.4986, Val Accuracy: 83.00%
# Epoch [179/200], Train Loss: 0.4608, Train Accuracy: 83.29%, Val Loss: 0.5009, Val Accuracy: 82.50%
# Epoch [180/200], Train Loss: 0.4606, Train Accuracy: 83.25%, Val Loss: 0.5027, Val Accuracy: 82.67%
# ...
# Epoch [142/300], Train Loss: 0.0161, Train Accuracy: 99.83%, Val Loss: 0.8790, Val Accuracy: 81.50%
# Epoch [143/300], Train Loss: 0.0165, Train Accuracy: 99.83%, Val Loss: 0.8803, Val Accuracy: 81.67%
# Epoch [144/300], Train Loss: 0.0159, Train Accuracy: 99.83%, Val Loss: 0.8748, Val Accuracy: 81.33%
# Epoch [145/300], Train Loss: 0.0159, Train Accuracy: 99.83%, Val Loss: 0.8772, Val Accuracy: 81.67%
# Epoch [146/300], Train Loss: 0.0158, Train Accuracy: 99.83%, Val Loss: 0.8641, Val Accuracy: 81.42%
# Epoch [147/300], Train Loss: 0.0158, Train Accuracy: 99.83%, Val Loss: 0.8703, Val Accuracy: 81.17%
# Epoch [148/300], Train Loss: 0.0157, Train Accuracy: 99.83%, Val Loss: 0.8711, Val Accuracy: 81.75%
# Epoch [149/300], Train Loss: 0.0156, Train Accuracy: 99.83%, Val Loss: 0.8788, Val Accuracy: 81.25%
# Epoch [150/300], Train Loss: 0.0156, Train Accuracy: 99.83%, Val Loss: 0.8732, Val Accuracy: 81.58%
# Epoch [151/300], Train Loss: 0.0154, Train Accuracy: 99.83%, Val Loss: 0.8748, Val Accuracy: 81.42%
# Epoch [152/300], Train Loss: 0.0154, Train Accuracy: 99.83%, Val Loss: 0.8755, Val Accuracy: 81.50%
# Epoch [153/300], Train Loss: 0.0155, Train Accuracy: 99.83%, Val Loss: 0.8715, Val Accuracy: 81.67%
# Epoch [154/300], Train Loss: 0.0154, Train Accuracy: 99.83%, Val Loss: 0.8730, Val Accuracy: 81.58%
# Epoch [155/300], Train Loss: 0.0155, Train Accuracy: 99.83%, Val Loss: 0.8746, Val Accuracy: 81.42%
# Epoch [156/300], Train Loss: 0.0152, Train Accuracy: 99.83%, Val Loss: 0.8775, Val Accuracy: 81.33%
# Epoch [157/300], Train Loss: 0.0152, Train Accuracy: 99.83%, Val Loss: 0.8784, Val Accuracy: 81.00%
# Epoch [158/300], Train Loss: 0.0153, Train Accuracy: 99.83%, Val Loss: 0.8745, Val Accuracy: 81.08%
# Epoch [159/300], Train Loss: 0.0152, Train Accuracy: 99.83%, Val Loss: 0.8764, Val Accuracy: 81.17%
# Epoch [160/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8759, Val Accuracy: 81.25%
# Epoch [161/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8785, Val Accuracy: 81.33%
# Epoch [162/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8743, Val Accuracy: 81.17%
# Epoch [163/300], Train Loss: 0.0150, Train Accuracy: 99.83%, Val Loss: 0.8780, Val Accuracy: 81.25%
# Epoch [164/300], Train Loss: 0.0150, Train Accuracy: 99.83%, Val Loss: 0.8733, Val Accuracy: 82.00%
# Epoch [165/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8803, Val Accuracy: 80.92%
# Epoch [166/300], Train Loss: 0.0150, Train Accuracy: 99.83%, Val Loss: 0.8781, Val Accuracy: 81.17%
# Epoch [167/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8750, Val Accuracy: 81.42%
# Epoch [168/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8771, Val Accuracy: 81.42%
# Epoch [169/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8760, Val Accuracy: 81.08%
# Epoch [170/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8743, Val Accuracy: 81.42%
# Epoch [171/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8769, Val Accuracy: 81.50%
# Epoch [172/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8722, Val Accuracy: 81.17%
# Epoch [173/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8779, Val Accuracy: 81.67%
# Epoch [174/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8754, Val Accuracy: 81.58%
# Epoch [175/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8778, Val Accuracy: 81.58%
# Epoch [176/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8780, Val Accuracy: 81.50%
# Epoch [177/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8750, Val Accuracy: 81.42%
# Epoch [178/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8758, Val Accuracy: 81.17%
# Epoch [179/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8755, Val Accuracy: 81.25%
# Epoch [180/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8749, Val Accuracy: 81.08%
# Epoch [181/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8758, Val Accuracy: 81.25%
# Epoch [182/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8772, Val Accuracy: 81.25%
# Epoch [183/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8747, Val Accuracy: 81.25%
# Epoch [184/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8769, Val Accuracy: 81.42%
# Epoch [185/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8763, Val Accuracy: 81.17%
# Epoch [186/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.33%
# Epoch [187/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8765, Val Accuracy: 81.25%
# Epoch [188/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8763, Val Accuracy: 81.33%
# Epoch [189/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8763, Val Accuracy: 81.42%
# Epoch [190/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8762, Val Accuracy: 81.25%
# Epoch [191/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8763, Val Accuracy: 81.50%
# Epoch [192/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8758, Val Accuracy: 81.25%
# Epoch [193/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8759, Val Accuracy: 81.33%
# Epoch [194/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.33%
# Epoch [195/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [196/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [197/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8760, Val Accuracy: 81.42%
# Epoch [198/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [199/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [200/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [201/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [202/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [203/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [204/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [205/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [206/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [207/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8760, Val Accuracy: 81.42%
# Epoch [208/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8759, Val Accuracy: 81.42%
# Epoch [209/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8758, Val Accuracy: 81.25%
# Epoch [210/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [211/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.33%
# Epoch [212/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.42%
# Epoch [213/300], Train Loss: 0.0144, Train Accuracy: 99.83%, Val Loss: 0.8759, Val Accuracy: 81.33%
# Epoch [214/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8762, Val Accuracy: 81.42%
# Epoch [215/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8760, Val Accuracy: 81.42%
# Epoch [216/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8763, Val Accuracy: 81.17%
# Epoch [217/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8766, Val Accuracy: 81.42%
# Epoch [218/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8765, Val Accuracy: 81.25%
# Epoch [219/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8772, Val Accuracy: 81.25%
# Epoch [220/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8765, Val Accuracy: 81.42%
# Epoch [221/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8769, Val Accuracy: 80.92%
# Epoch [222/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8765, Val Accuracy: 81.25%
# Epoch [223/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8761, Val Accuracy: 81.17%
# Epoch [224/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8770, Val Accuracy: 81.25%
# Epoch [225/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8775, Val Accuracy: 81.33%
# Epoch [226/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8763, Val Accuracy: 81.25%
# Epoch [227/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8755, Val Accuracy: 81.33%
# Epoch [228/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8788, Val Accuracy: 81.33%
# Epoch [229/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8781, Val Accuracy: 81.50%
# Epoch [230/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8734, Val Accuracy: 81.33%
# Epoch [231/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8815, Val Accuracy: 81.50%
# Epoch [232/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8771, Val Accuracy: 81.50%
# Epoch [233/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8775, Val Accuracy: 81.58%
# Epoch [234/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8757, Val Accuracy: 81.42%
# Epoch [235/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8798, Val Accuracy: 81.42%
# Epoch [236/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8784, Val Accuracy: 81.50%
# Epoch [237/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8823, Val Accuracy: 81.17%
# Epoch [238/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8754, Val Accuracy: 81.58%
# Epoch [239/300], Train Loss: 0.0150, Train Accuracy: 99.83%, Val Loss: 0.8820, Val Accuracy: 81.33%
# Epoch [240/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8751, Val Accuracy: 81.42%
# Epoch [241/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8803, Val Accuracy: 81.08%
# Epoch [242/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8858, Val Accuracy: 81.25%
# Epoch [243/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8843, Val Accuracy: 81.25%
# Epoch [244/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8835, Val Accuracy: 81.33%
# Epoch [245/300], Train Loss: 0.0150, Train Accuracy: 99.83%, Val Loss: 0.8785, Val Accuracy: 81.25%
# Epoch [246/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8793, Val Accuracy: 81.83%
# Epoch [247/300], Train Loss: 0.0150, Train Accuracy: 99.83%, Val Loss: 0.8837, Val Accuracy: 81.50%
# Epoch [248/300], Train Loss: 0.0155, Train Accuracy: 99.83%, Val Loss: 0.8830, Val Accuracy: 80.92%
# Epoch [249/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8879, Val Accuracy: 81.33%
# Epoch [250/300], Train Loss: 0.0168, Train Accuracy: 99.81%, Val Loss: 0.8777, Val Accuracy: 80.92%
# Epoch [251/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8802, Val Accuracy: 81.58%
# Epoch [252/300], Train Loss: 0.0150, Train Accuracy: 99.83%, Val Loss: 0.8797, Val Accuracy: 81.58%
# Epoch [253/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8762, Val Accuracy: 81.33%
# Epoch [254/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8819, Val Accuracy: 81.42%
# Epoch [255/300], Train Loss: 0.0152, Train Accuracy: 99.83%, Val Loss: 0.8787, Val Accuracy: 81.25%
# Epoch [256/300], Train Loss: 0.0152, Train Accuracy: 99.83%, Val Loss: 0.8818, Val Accuracy: 81.42%
# Epoch [257/300], Train Loss: 0.0157, Train Accuracy: 99.83%, Val Loss: 0.8837, Val Accuracy: 81.75%
# Epoch [258/300], Train Loss: 0.0152, Train Accuracy: 99.83%, Val Loss: 0.8822, Val Accuracy: 80.92%
# Epoch [259/300], Train Loss: 0.0156, Train Accuracy: 99.83%, Val Loss: 0.8849, Val Accuracy: 80.75%
# Epoch [260/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8837, Val Accuracy: 80.83%
# Epoch [261/300], Train Loss: 0.0160, Train Accuracy: 99.81%, Val Loss: 0.8813, Val Accuracy: 81.67%
# Epoch [262/300], Train Loss: 0.0153, Train Accuracy: 99.83%, Val Loss: 0.8802, Val Accuracy: 81.83%
# Epoch [263/300], Train Loss: 0.0154, Train Accuracy: 99.83%, Val Loss: 0.8798, Val Accuracy: 80.83%
# Epoch [264/300], Train Loss: 0.0174, Train Accuracy: 99.83%, Val Loss: 0.8899, Val Accuracy: 80.67%
# Epoch [265/300], Train Loss: 0.0156, Train Accuracy: 99.83%, Val Loss: 0.8854, Val Accuracy: 81.17%
# Epoch [266/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8893, Val Accuracy: 81.42%
# Epoch [267/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.8926, Val Accuracy: 81.08%
# Epoch [268/300], Train Loss: 0.0163, Train Accuracy: 99.83%, Val Loss: 0.8815, Val Accuracy: 81.42%
# Epoch [269/300], Train Loss: 0.0154, Train Accuracy: 99.83%, Val Loss: 0.8915, Val Accuracy: 81.58%
# Epoch [270/300], Train Loss: 0.0161, Train Accuracy: 99.83%, Val Loss: 0.8912, Val Accuracy: 81.42%
# Epoch [271/300], Train Loss: 0.0166, Train Accuracy: 99.81%, Val Loss: 0.8828, Val Accuracy: 81.50%
# Epoch [272/300], Train Loss: 0.0160, Train Accuracy: 99.83%, Val Loss: 0.8903, Val Accuracy: 81.08%
# Epoch [273/300], Train Loss: 0.0154, Train Accuracy: 99.83%, Val Loss: 0.8896, Val Accuracy: 80.83%
# Epoch [274/300], Train Loss: 0.0152, Train Accuracy: 99.83%, Val Loss: 0.8952, Val Accuracy: 81.67%
# Epoch [275/300], Train Loss: 0.0160, Train Accuracy: 99.83%, Val Loss: 0.8909, Val Accuracy: 80.75%
# Epoch [276/300], Train Loss: 0.0168, Train Accuracy: 99.83%, Val Loss: 0.8974, Val Accuracy: 81.17%
# Epoch [277/300], Train Loss: 0.0174, Train Accuracy: 99.83%, Val Loss: 0.8886, Val Accuracy: 81.42%
# Epoch [278/300], Train Loss: 0.0155, Train Accuracy: 99.83%, Val Loss: 0.8830, Val Accuracy: 81.42%
# Epoch [279/300], Train Loss: 0.0157, Train Accuracy: 99.83%, Val Loss: 0.8987, Val Accuracy: 80.75%
# Epoch [280/300], Train Loss: 0.0162, Train Accuracy: 99.83%, Val Loss: 0.8972, Val Accuracy: 81.08%
# Epoch [281/300], Train Loss: 0.0156, Train Accuracy: 99.83%, Val Loss: 0.8977, Val Accuracy: 81.42%
# Epoch [282/300], Train Loss: 0.0169, Train Accuracy: 99.79%, Val Loss: 0.8969, Val Accuracy: 81.58%
# Epoch [283/300], Train Loss: 0.0257, Train Accuracy: 99.65%, Val Loss: 0.8969, Val Accuracy: 81.25%
# Epoch [284/300], Train Loss: 0.0195, Train Accuracy: 99.73%, Val Loss: 0.8977, Val Accuracy: 81.50%
# Epoch [285/300], Train Loss: 0.0154, Train Accuracy: 99.83%, Val Loss: 0.9001, Val Accuracy: 81.83%
# Epoch [286/300], Train Loss: 0.0166, Train Accuracy: 99.79%, Val Loss: 0.8958, Val Accuracy: 81.25%
# Epoch [287/300], Train Loss: 0.0251, Train Accuracy: 99.54%, Val Loss: 0.8902, Val Accuracy: 81.50%
# Epoch [288/300], Train Loss: 0.0161, Train Accuracy: 99.81%, Val Loss: 0.8952, Val Accuracy: 81.50%
# Epoch [289/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.8981, Val Accuracy: 81.08%
# Epoch [290/300], Train Loss: 0.0146, Train Accuracy: 99.83%, Val Loss: 0.8926, Val Accuracy: 81.25%
# Epoch [291/300], Train Loss: 0.0148, Train Accuracy: 99.83%, Val Loss: 0.8890, Val Accuracy: 80.83%
# Epoch [292/300], Train Loss: 0.0149, Train Accuracy: 99.83%, Val Loss: 0.9009, Val Accuracy: 81.42%
# Epoch [293/300], Train Loss: 0.0151, Train Accuracy: 99.83%, Val Loss: 0.9053, Val Accuracy: 81.00%
# Epoch [294/300], Train Loss: 0.0299, Train Accuracy: 99.38%, Val Loss: 0.9210, Val Accuracy: 80.92%
# Epoch [295/300], Train Loss: 0.0239, Train Accuracy: 99.69%, Val Loss: 0.9063, Val Accuracy: 80.75%
# Epoch [296/300], Train Loss: 0.0160, Train Accuracy: 99.81%, Val Loss: 0.8994, Val Accuracy: 81.33%
# Epoch [297/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.9060, Val Accuracy: 81.33%
# Epoch [298/300], Train Loss: 0.0147, Train Accuracy: 99.83%, Val Loss: 0.8939, Val Accuracy: 81.25%
# Epoch [299/300], Train Loss: 0.0143, Train Accuracy: 99.83%, Val Loss: 0.8912, Val Accuracy: 81.33%
# Epoch [300/300], Train Loss: 0.0145, Train Accuracy: 99.83%, Val Loss: 0.8964, Val Accuracy: 80.92%
# Model Training Time: 565.041 s
# Model Accutacy:80.02
#
# Top 3 Model:model6,model5,model7
